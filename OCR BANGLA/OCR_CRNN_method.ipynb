# %%
# !unzip "/content/drive/MyDrive/BanglaWriting Extracted.zip"
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: BanglaWriting Extracted/raw/16036_বলা.jpg
#   inflating: BanglaWriting Extracted/raw/16037_সেখানেই.jpg
#   inflating: BanglaWriting Extracted/raw/16038_বছরের.jpg
#   inflating: BanglaWriting Extracted/raw/16039_।.jpg
#   inflating: BanglaWriting Extracted/raw/1603_কু.jpg
#   inflating: BanglaWriting Extracted/raw/16040_আমি.jpg
#   inflating: BanglaWriting Extracted/raw/16041_যে.jpg
#   inflating: BanglaWriting Extracted/raw/16042_খানেই.jpg
#   inflating: BanglaWriting Extracted/raw/16043_যাই.jpg
#   inflating: BanglaWriting Extracted/raw/16044_অভিজ্ঞতা.jpg
#   inflating: BanglaWriting Extracted/raw/16045_কত.jpg
#   inflating: BanglaWriting Extracted/raw/16046_দিনের.jpg
#   inflating: BanglaWriting Extracted/raw/16047_বা.jpg
#   inflating: BanglaWriting Extracted/raw/16048_সাইন্সে.jpg
#   inflating: BanglaWriting Extracted/raw/16049_ডিপ্লোমা.jpg
#   inflating: BanglaWriting Extracted/raw/1604_বুদ্ধি.jpg
#   inflating: BanglaWriting Extracted/raw/16051_ছাত্র.jpg
#   inflating: BanglaWriting Extracted/raw/16052_।.jpg
#   inflating: BanglaWriting Extracted/raw/16053_আমি.jpg
#   inflating: BanglaWriting Extracted/raw/16054_আমার.jpg
#   inflating: BanglaWriting Extracted/raw/16055_পড়া.jpg
#   inflating: BanglaWriting Extracted/raw/16056_২০১৭.jpg
#   inflating: BanglaWriting Extracted/raw/16057_সালে.jpg
#   inflating: BanglaWriting Extracted/raw/16058_শেষ.jpg
#   inflating: BanglaWriting Extracted/raw/16059_করি.jpg
#   inflating: BanglaWriting Extracted/raw/1605_দ্বারা.jpg
#   inflating: BanglaWriting Extracted/raw/16060_।.jpg
#   inflating: BanglaWriting Extracted/raw/16061_আমি.jpg
#   inflating: BanglaWriting Extracted/raw/16062_বি.jpg
#   inflating: BanglaWriting Extracted/raw/16063_ডি.jpg
#   inflating: BanglaWriting Extracted/raw/16064_জবসে.jpg
#   inflating: BanglaWriting Extracted/raw/16065_যখন.jpg
#   inflating: BanglaWriting Extracted/raw/16066_এপ্লাই.jpg
#   inflating: BanglaWriting Extracted/raw/16067_করতে.jpg
#   inflating: BanglaWriting Extracted/raw/16069_সেখানে.jpg
#   inflating: BanglaWriting Extracted/raw/1606_কু.jpg
#   inflating: BanglaWriting Extracted/raw/16070_বলা.jpg
#   inflating: BanglaWriting Extracted/raw/16071_থাকে.jpg
#   inflating: BanglaWriting Extracted/raw/16072_২.jpg
#   inflating: BanglaWriting Extracted/raw/16073_-.jpg
#   inflating: BanglaWriting Extracted/raw/16074_৩.jpg
#   inflating: BanglaWriting Extracted/raw/16075_বছরের.jpg
#   inflating: BanglaWriting Extracted/raw/16076_অভিজ্ঞতা.jpg
#   inflating: BanglaWriting Extracted/raw/16077_না.jpg
#   inflating: BanglaWriting Extracted/raw/16078_থকলে.jpg
#   inflating: BanglaWriting Extracted/raw/16079_আবেদন.jpg
#   inflating: BanglaWriting Extracted/raw/1607_-.jpg
#   inflating: BanglaWriting Extracted/raw/16080_করার.jpg
#   inflating: BanglaWriting Extracted/raw/16081_প্রয়োজন.jpg
#   inflating: BanglaWriting Extracted/raw/16082_নাই.jpg
#   inflating: BanglaWriting Extracted/raw/16083_।.jpg
#   inflating: BanglaWriting Extracted/raw/16084_যখন.jpg
#   inflating: BanglaWriting Extracted/raw/16087_দোকানে.jpg
#   inflating: BanglaWriting Extracted/raw/16088_যাই.jpg
#   inflating: BanglaWriting Extracted/raw/16089_তখন.jpg
#   inflating: BanglaWriting Extracted/raw/1608_কর্মের.jpg
#   inflating: BanglaWriting Extracted/raw/16091_৪.jpg
#   inflating: BanglaWriting Extracted/raw/16092_-.jpg
#   inflating: BanglaWriting Extracted/raw/16093_৫.jpg
#   inflating: BanglaWriting Extracted/raw/16094_বছরের.jpg
#   inflating: BanglaWriting Extracted/raw/16095_অভিজ্ঞতা.jpg
#   inflating: BanglaWriting Extracted/raw/16096_লাগবে.jpg
#   inflating: BanglaWriting Extracted/raw/16097_।.jpg
#   inflating: BanglaWriting Extracted/raw/16098_আচ্ছা.jpg
#   inflating: BanglaWriting Extracted/raw/16099_স্যার.jpg
#   inflating: BanglaWriting Extracted/raw/1609_রত.jpg
#   inflating: BanglaWriting Extracted/raw/160_মনে.jpg
#   inflating: BanglaWriting Extracted/raw/16100_আপনিই.jpg
#   inflating: BanglaWriting Extracted/raw/16101_বলেন.jpg
#   inflating: BanglaWriting Extracted/raw/16103_ছাত্র.jpg
#   inflating: BanglaWriting Extracted/raw/16104_যখন.jpg
#   inflating: BanglaWriting Extracted/raw/16105_কলেজ.jpg
#   inflating: BanglaWriting Extracted/raw/16106_থেকে.jpg
#   inflating: BanglaWriting Extracted/raw/16107_পাশ.jpg
#   inflating: BanglaWriting Extracted/raw/16108_করে.jpg
#   inflating: BanglaWriting Extracted/raw/16109_বের.jpg
#   inflating: BanglaWriting Extracted/raw/1610_হয়.jpg
#   inflating: BanglaWriting Extracted/raw/16110_হয়.jpg
#   inflating: BanglaWriting Extracted/raw/16111_তখন.jpg
#   inflating: BanglaWriting Extracted/raw/16112_কি.jpg
#   inflating: BanglaWriting Extracted/raw/16113_তার.jpg
#   inflating: BanglaWriting Extracted/raw/16114_বাস্তব.jpg
#   inflating: BanglaWriting Extracted/raw/16115_অভিজ্ঞতা.jpg
#   inflating: BanglaWriting Extracted/raw/16116_থাকে.jpg
#   inflating: BanglaWriting Extracted/raw/16118_সে.jpg
#   inflating: BanglaWriting Extracted/raw/16119_কিভাবে.jpg
#   inflating: BanglaWriting Extracted/raw/16120_তার.jpg
#   inflating: BanglaWriting Extracted/raw/16121_অভিজ্ঞতা.jpg
#   inflating: BanglaWriting Extracted/raw/16122_দেখাবে.jpg
#   inflating: BanglaWriting Extracted/raw/16123_।.jpg
#   inflating: BanglaWriting Extracted/raw/16124_আমার.jpg
#   inflating: BanglaWriting Extracted/raw/16125_এটাই.jpg
#   inflating: BanglaWriting Extracted/raw/16126_আফসোস.jpg
#   inflating: BanglaWriting Extracted/raw/16127_।.jpg
#   inflating: BanglaWriting Extracted/raw/16128_আমি.jpg
#   inflating: BanglaWriting Extracted/raw/16129_কিভাবে.jpg
#   inflating: BanglaWriting Extracted/raw/1612_ব্যক্তি.jpg
#   inflating: BanglaWriting Extracted/raw/16130_তাদের.jpg
#   inflating: BanglaWriting Extracted/raw/16131_অভিজ্ঞতা.jpg
#   inflating: BanglaWriting Extracted/raw/16132_দেখাবো.jpg
#   inflating: BanglaWriting Extracted/raw/16133_মিথ্যা.jpg
#   inflating: BanglaWriting Extracted/raw/16134_বলে.jpg
#   inflating: BanglaWriting Extracted/raw/16136_নাকি.jpg
#   inflating: BanglaWriting Extracted/raw/16138_স্যার.jpg
#   inflating: BanglaWriting Extracted/raw/16139_যখন.jpg
#   inflating: BanglaWriting Extracted/raw/1613_বিদ্বান.jpg
#   inflating: BanglaWriting Extracted/raw/16140_এসব.jpg
#   inflating: BanglaWriting Extracted/raw/16141_জায়গায়.jpg
#   inflating: BanglaWriting Extracted/raw/16142_কাজ.jpg
#   inflating: BanglaWriting Extracted/raw/16143_পেলাম.jpg
#   inflating: BanglaWriting Extracted/raw/16144_না.jpg
#   inflating: BanglaWriting Extracted/raw/16145_তাই.jpg
#   inflating: BanglaWriting Extracted/raw/16146_গার্মেন্টস.jpg
#   inflating: BanglaWriting Extracted/raw/16147_এ.jpg
#   inflating: BanglaWriting Extracted/raw/16148_গেলাম.jpg
#   inflating: BanglaWriting Extracted/raw/1614_হলেও.jpg
#   inflating: BanglaWriting Extracted/raw/16150_বলে.jpg
#   inflating: BanglaWriting Extracted/raw/16151_আপনার.jpg
#   inflating: BanglaWriting Extracted/raw/16152_অভিজ্ঞতা.jpg
#   inflating: BanglaWriting Extracted/raw/16153_।.jpg
#   inflating: BanglaWriting Extracted/raw/16154_স্যার.jpg
#   inflating: BanglaWriting Extracted/raw/16155_আমার.jpg
#   inflating: BanglaWriting Extracted/raw/16156_কি.jpg
#   inflating: BanglaWriting Extracted/raw/16157_আই.jpg
#   inflating: BanglaWriting Extracted/raw/16158_টি.jpg
#   inflating: BanglaWriting Extracted/raw/16159_বিষয়.jpg
#   inflating: BanglaWriting Extracted/raw/1615_সমাজের.jpg
#   inflating: BanglaWriting Extracted/raw/16160_ছেরে.jpg
#   inflating: BanglaWriting Extracted/raw/16161_গার্মেন্টস.jpg
#   inflating: BanglaWriting Extracted/raw/16162_এর.jpg
#   inflating: BanglaWriting Extracted/raw/16163_সুতা.jpg
#   inflating: BanglaWriting Extracted/raw/16164_বাছার.jpg
#   inflating: BanglaWriting Extracted/raw/16165_কাজ.jpg
#   inflating: BanglaWriting Extracted/raw/16166_ভালো.jpg
#   inflating: BanglaWriting Extracted/raw/16167_লাগবে.jpg
#   inflating: BanglaWriting Extracted/raw/16169_আমার.jpg
#   inflating: BanglaWriting Extracted/raw/16189_রাষ্ট্রক্ষমতা.jpg
#   inflating: BanglaWriting Extracted/raw/1618_।.jpg
#   inflating: BanglaWriting Extracted/raw/16190_দখল.jpg
#   inflating: BanglaWriting Extracted/raw/16191_করে.jpg
#   inflating: BanglaWriting Extracted/raw/16192_নেয়.jpg
#   inflating: BanglaWriting Extracted/raw/16193_।.jpg
#   inflating: BanglaWriting Extracted/raw/16194_এদের.jpg
#   inflating: BanglaWriting Extracted/raw/16195_ইংরেজ.jpg
#   inflating: BanglaWriting Extracted/raw/16196_ইস্ট.jpg
#   inflating: BanglaWriting Extracted/raw/16197_ইন্ডিয়া.jpg
#   inflating: BanglaWriting Extracted/raw/16198_কোম্পানি.jpg
#   inflating: BanglaWriting Extracted/raw/16199_প্রতিযোগিতায়.jpg
#   inflating: BanglaWriting Extracted/raw/1619_আমরা.jpg
#   inflating: BanglaWriting Extracted/raw/16200_এগিয়ে.jpg
#   inflating: BanglaWriting Extracted/raw/16201_যায়.jpg
#   inflating: BanglaWriting Extracted/raw/16202_।.jpg
#   inflating: BanglaWriting Extracted/raw/16203_১৭৫৭.jpg
#   inflating: BanglaWriting Extracted/raw/16205_বাংলা.jpg
#   inflating: BanglaWriting Extracted/raw/16206_বিহার.jpg
#   inflating: BanglaWriting Extracted/raw/16207_ও.jpg
#   inflating: BanglaWriting Extracted/raw/16208_উড়িষ্যার.jpg
#   inflating: BanglaWriting Extracted/raw/16209_নবাব.jpg
#   inflating: BanglaWriting Extracted/raw/1620_যেখানে.jpg
#   inflating: BanglaWriting Extracted/raw/16210_সিরাজ.jpg
#   inflating: BanglaWriting Extracted/raw/16211_উদ্দৌলাকে.jpg
#   inflating: BanglaWriting Extracted/raw/16212_পরাজিত.jpg
#   inflating: BanglaWriting Extracted/raw/16213_করে.jpg
#   inflating: BanglaWriting Extracted/raw/16214_এক.jpg
#   inflating: BanglaWriting Extracted/raw/16215_সময়.jpg
#   inflating: BanglaWriting Extracted/raw/16216_তারা.jpg
#   inflating: BanglaWriting Extracted/raw/16217_ক্ষমতা.jpg
#   inflating: BanglaWriting Extracted/raw/16218_দখল.jpg
#   inflating: BanglaWriting Extracted/raw/16219_করে.jpg
#   inflating: BanglaWriting Extracted/raw/1621_বসবাস.jpg
#   inflating: BanglaWriting Extracted/raw/16221_।.jpg
#   inflating: BanglaWriting Extracted/raw/16222_বাংলায়.jpg
#   inflating: BanglaWriting Extracted/raw/16223_ইরেজীদের.jpg
#   inflating: BanglaWriting Extracted/raw/16224_শাসন.jpg
#   inflating: BanglaWriting Extracted/raw/16225_চলে.jpg
#   inflating: BanglaWriting Extracted/raw/16226_১৯৪৭.jpg
#   inflating: BanglaWriting Extracted/raw/16229_এদেশের.jpg
#   inflating: BanglaWriting Extracted/raw/1622_করি.jpg
#   inflating: BanglaWriting Extracted/raw/16230_বেশির.jpg
#   inflating: BanglaWriting Extracted/raw/16231_ভাগ.jpg
#   inflating: BanglaWriting Extracted/raw/16232_লোক.jpg
#   inflating: BanglaWriting Extracted/raw/16233_গ্রামে.jpg
#   inflating: BanglaWriting Extracted/raw/16234_বাস.jpg
#   inflating: BanglaWriting Extracted/raw/16235_করে.jpg
#   inflating: BanglaWriting Extracted/raw/16236_।.jpg
#   inflating: BanglaWriting Extracted/raw/16237_আর.jpg
#   inflating: BanglaWriting Extracted/raw/16238_কৃষিই.jpg
#   inflating: BanglaWriting Extracted/raw/1623_,.jpg
#   inflating: BanglaWriting Extracted/raw/16240_জীবিকার.jpg
#   inflating: BanglaWriting Extracted/raw/16241_প্রধান.jpg
#   inflating: BanglaWriting Extracted/raw/16242_উপায়.jpg
#   inflating: BanglaWriting Extracted/raw/16243_।.jpg
#   inflating: BanglaWriting Extracted/raw/16244_এছাড়া.jpg
#   inflating: BanglaWriting Extracted/raw/16245_ও.jpg
#   inflating: BanglaWriting Extracted/raw/16246_শহর.jpg
#   inflating: BanglaWriting Extracted/raw/16247_বা.jpg
#   inflating: BanglaWriting Extracted/raw/16248_গ্রামাঞ্চলে.jpg
#   inflating: BanglaWriting Extracted/raw/16249_কিছু.jpg
#   inflating: BanglaWriting Extracted/raw/1624_সেখানে.jpg
#   inflating: BanglaWriting Extracted/raw/16250_লোক.jpg
#   inflating: BanglaWriting Extracted/raw/16251_যেমনঃ.jpg
#   inflating: BanglaWriting Extracted/raw/16252_তাঁতি.jpg
#   inflating: BanglaWriting Extracted/raw/16253_,.jpg
#   inflating: BanglaWriting Extracted/raw/16254_জেলে.jpg
#   inflating: BanglaWriting Extracted/raw/16256_কুমার.jpg
#   inflating: BanglaWriting Extracted/raw/16257_,.jpg
#   inflating: BanglaWriting Extracted/raw/16258_কামার.jpg
#   inflating: BanglaWriting Extracted/raw/16259_,.jpg
#   inflating: BanglaWriting Extracted/raw/1625_আমাদেকে.jpg
#   inflating: BanglaWriting Extracted/raw/16260_ও.jpg
#   inflating: BanglaWriting Extracted/raw/16261_ব্যবসা.jpg
#   inflating: BanglaWriting Extracted/raw/16262_বাণিজ্য.jpg
#   inflating: BanglaWriting Extracted/raw/16263_করে.jpg
#   inflating: BanglaWriting Extracted/raw/16264_।.jpg
#   inflating: BanglaWriting Extracted/raw/16265_এছাড়া.jpg
#   inflating: BanglaWriting Extracted/raw/16266_ও.jpg
#   inflating: BanglaWriting Extracted/raw/16267_শহরে.jpg
#   inflating: BanglaWriting Extracted/raw/16268_বহু.jpg
#   inflating: BanglaWriting Extracted/raw/16269_লোক.jpg
#   inflating: BanglaWriting Extracted/raw/1626_কেন্দ্র.jpg
#   inflating: BanglaWriting Extracted/raw/16270_রিক্সা.jpg
#   inflating: BanglaWriting Extracted/raw/16271_,.jpg
#   inflating: BanglaWriting Extracted/raw/16273_ও.jpg
#   inflating: BanglaWriting Extracted/raw/16274_ভ্যান.jpg
#   inflating: BanglaWriting Extracted/raw/16275_গাড়ি.jpg
#   inflating: BanglaWriting Extracted/raw/16276_চালক.jpg
#   inflating: BanglaWriting Extracted/raw/16277_,.jpg
#   inflating: BanglaWriting Extracted/raw/16278_মুটে.jpg
#   inflating: BanglaWriting Extracted/raw/16279_,.jpg
#   inflating: BanglaWriting Extracted/raw/1627_করে.jpg
#   inflating: BanglaWriting Extracted/raw/16280_মজুর.jpg
#   inflating: BanglaWriting Extracted/raw/16281_,.jpg
#   inflating: BanglaWriting Extracted/raw/16282_ছোট.jpg
#   inflating: BanglaWriting Extracted/raw/16283_দোকানদার.jpg
#   inflating: BanglaWriting Extracted/raw/16284_ও.jpg
#   inflating: BanglaWriting Extracted/raw/16285_ফেরি.jpg
#   inflating: BanglaWriting Extracted/raw/16286_ওয়ালা.jpg
#   inflating: BanglaWriting Extracted/raw/16287_ইত্যাদি.jpg
#   inflating: BanglaWriting Extracted/raw/16288_হিসাবে.jpg
#   inflating: BanglaWriting Extracted/raw/1628_গড়ে.jpg
#   inflating: BanglaWriting Extracted/raw/16290_ধারণ.jpg
#   inflating: BanglaWriting Extracted/raw/16291_করে.jpg
#   inflating: BanglaWriting Extracted/raw/16292_।.jpg
#   inflating: BanglaWriting Extracted/raw/16293_এসব.jpg
#   inflating: BanglaWriting Extracted/raw/16294_কাজ.jpg
#   inflating: BanglaWriting Extracted/raw/16295_হয়.jpg
#   inflating: BanglaWriting Extracted/raw/16296_ব্যক্তি.jpg
#   inflating: BanglaWriting Extracted/raw/16297_উদ্যোগে.jpg
#   inflating: BanglaWriting Extracted/raw/16298_।.jpg
#   inflating: BanglaWriting Extracted/raw/16299_পাশাপাশি.jpg
#   inflating: BanglaWriting Extracted/raw/1629_উঠে.jpg
#   inflating: BanglaWriting Extracted/raw/162_সকল.jpg
#   inflating: BanglaWriting Extracted/raw/16300_রাষ্ট্রীয়.jpg
#   inflating: BanglaWriting Extracted/raw/16301_প্রধান.jpg
#   inflating: BanglaWriting Extracted/raw/16302_।.jpg
#   inflating: BanglaWriting Extracted/raw/16303_মানব.jpg
#   inflating: BanglaWriting Extracted/raw/16306_সব.jpg
#   inflating: BanglaWriting Extracted/raw/16307_লোকে.jpg
#   inflating: BanglaWriting Extracted/raw/16308_কয়.jpg
#   inflating: BanglaWriting Extracted/raw/16309_লালান.jpg
#   inflating: BanglaWriting Extracted/raw/1630_স্থা.jpg
#   inflating: BanglaWriting Extracted/raw/16310_কী.jpg
#   inflating: BanglaWriting Extracted/raw/16311_জাত.jpg
#   inflating: BanglaWriting Extracted/raw/16312_সংস.jpg
#   inflating: BanglaWriting Extracted/raw/16313_লালন.jpg
#   inflating: BanglaWriting Extracted/raw/16314_কয়.jpg
#   inflating: BanglaWriting Extracted/raw/16315_,.jpg
#   inflating: BanglaWriting Extracted/raw/16316_জেতের.jpg
#   inflating: BanglaWriting Extracted/raw/16317_কী.jpg
#   inflating: BanglaWriting Extracted/raw/16319_,.jpg
#   inflating: BanglaWriting Extracted/raw/1631_-.jpg
#   inflating: BanglaWriting Extracted/raw/16320_দেখালাম.jpg
#   inflating: BanglaWriting Extracted/raw/16321_না.jpg
#   inflating: BanglaWriting Extracted/raw/16322_এ.jpg
#   inflating: BanglaWriting Extracted/raw/16324_।.jpg
#   inflating: BanglaWriting Extracted/raw/16325_কেউ.jpg
#   inflating: BanglaWriting Extracted/raw/16326_মালা.jpg
#   inflating: BanglaWriting Extracted/raw/16327_।.jpg
#   inflating: BanglaWriting Extracted/raw/16328_কেউ.jpg
#   inflating: BanglaWriting Extracted/raw/16329_তসবি.jpg
#   inflating: BanglaWriting Extracted/raw/1632_নীয়.jpg
#   inflating: BanglaWriting Extracted/raw/16330_গলায়.jpg
#   inflating: BanglaWriting Extracted/raw/16331_,.jpg
#   inflating: BanglaWriting Extracted/raw/16332_তাইতে.jpg
#   inflating: BanglaWriting Extracted/raw/16333_কী.jpg
#   inflating: BanglaWriting Extracted/raw/16334_জাত.jpg
#   inflating: BanglaWriting Extracted/raw/16335_ভিন্ন.jpg
#   inflating: BanglaWriting Extracted/raw/16336_।.jpg
#   inflating: BanglaWriting Extracted/raw/16337_যাওয়া.jpg
#   inflating: BanglaWriting Extracted/raw/16338_কীংবা.jpg
#   inflating: BanglaWriting Extracted/raw/16339_আসার.jpg
#   inflating: BanglaWriting Extracted/raw/1633_বিভিন্ন.jpg
#   inflating: BanglaWriting Extracted/raw/16340_বেলায়.jpg
#   inflating: BanglaWriting Extracted/raw/16341_জেতের.jpg
#   inflating: BanglaWriting Extracted/raw/16342_চিহ্ন.jpg
#   inflating: BanglaWriting Extracted/raw/16343_রয়.jpg
#   inflating: BanglaWriting Extracted/raw/16344_কার.jpg
#   inflating: BanglaWriting Extracted/raw/16345_রে.jpg
#   inflating: BanglaWriting Extracted/raw/16346_গর্তে.jpg
#   inflating: BanglaWriting Extracted/raw/16347_গেলে.jpg
#   inflating: BanglaWriting Extracted/raw/16348_কূপ.jpg
#   inflating: BanglaWriting Extracted/raw/16349_জল.jpg
#   inflating: BanglaWriting Extracted/raw/1636_যেমনঃ.jpg
#   inflating: BanglaWriting Extracted/raw/16370_(.jpg
#   inflating: BanglaWriting Extracted/raw/16372_শে.jpg
#   inflating: BanglaWriting Extracted/raw/16374_১৩০৩.jpg
#   inflating: BanglaWriting Extracted/raw/16375_সালে.jpg
#   inflating: BanglaWriting Extracted/raw/16376_).jpg
#   inflating: BanglaWriting Extracted/raw/16377_সাতক্ষীরা.jpg
#   inflating: BanglaWriting Extracted/raw/16378_জেলার.jpg
#   inflating: BanglaWriting Extracted/raw/16379_বাশঁদহ.jpg
#   inflating: BanglaWriting Extracted/raw/1637_পরিবার.jpg
#   inflating: BanglaWriting Extracted/raw/16380_গ্রামে.jpg
#   inflating: BanglaWriting Extracted/raw/16381_জন্মগ্রহন.jpg
#   inflating: BanglaWriting Extracted/raw/16382_করেন.jpg
#   inflating: BanglaWriting Extracted/raw/16383_।.jpg
#   inflating: BanglaWriting Extracted/raw/16385_বঙ্গবাসী.jpg
#   inflating: BanglaWriting Extracted/raw/16386_কলেজে.jpg
#   inflating: BanglaWriting Extracted/raw/16387_বিএ.jpg
#   inflating: BanglaWriting Extracted/raw/16323_নজরে.jpg
#   inflating: BanglaWriting Extracted/raw/1634_প্রতিষ্ঠান.jpg
#   inflating: BanglaWriting Extracted/raw/16369_সালে.jpg
#   inflating: BanglaWriting Extracted/raw/16388_ক্লাসের.jpg
#   inflating: BanglaWriting Extracted/raw/16405_তিনি.jpg
#   inflating: BanglaWriting Extracted/raw/16423_,.jpg
#   inflating: BanglaWriting Extracted/raw/16442_সৈয়দ.jpg
#   inflating: BanglaWriting Extracted/raw/16462_২৮.jpg
#   inflating: BanglaWriting Extracted/raw/1647_এদের.jpg
#   inflating: BanglaWriting Extracted/raw/16496_সাং.jpg
#   inflating: BanglaWriting Extracted/raw/1651_ও.jpg
#   inflating: BanglaWriting Extracted/raw/16537_ইত্যাদি.jpg
#   inflating: BanglaWriting Extracted/raw/16555_যা.jpg
#   inflating: BanglaWriting Extracted/raw/16572_যাবে.jpg
#   inflating: BanglaWriting Extracted/raw/16589_পুষ্টি.jpg
#   inflating: BanglaWriting Extracted/raw/16604_শোষণ.jpg
#   inflating: BanglaWriting Extracted/raw/16389_ছাত্র.jpg
#   inflating: BanglaWriting Extracted/raw/1638_সমাজ.jpg
#   inflating: BanglaWriting Extracted/raw/16390_থাকাকালীন.jpg
#   inflating: BanglaWriting Extracted/raw/16391_তিনি.jpg
#   inflating: BanglaWriting Extracted/raw/16392_অসহযোগ.jpg
#   inflating: BanglaWriting Extracted/raw/16393_আন্দোলন.jpg
#   inflating: BanglaWriting Extracted/raw/16394_হিসেবে.jpg
#   inflating: BanglaWriting Extracted/raw/16395_যোগদান.jpg
#   inflating: BanglaWriting Extracted/raw/16397_এবং.jpg
#   inflating: BanglaWriting Extracted/raw/16398_এখানেই.jpg
#   inflating: BanglaWriting Extracted/raw/16399_লেখাপড়ার.jpg
#   inflating: BanglaWriting Extracted/raw/1639_রাষ্ট্র.jpg
#   inflating: BanglaWriting Extracted/raw/163_ছেলে.jpg
#   inflating: BanglaWriting Extracted/raw/16400_মাপ্তি.jpg
#   inflating: BanglaWriting Extracted/raw/16402_ঘটান.jpg
#   inflating: BanglaWriting Extracted/raw/16403_।.jpg
#   inflating: BanglaWriting Extracted/raw/16404_এরপর.jpg
#   inflating: BanglaWriting Extracted/raw/16406_সাংবাদিকতাকে.jpg
#   inflating: BanglaWriting Extracted/raw/16407_পেশা.jpg
#   inflating: BanglaWriting Extracted/raw/16408_হিসেবে.jpg
#   inflating: BanglaWriting Extracted/raw/16409_গ্রহণ.jpg
#   inflating: BanglaWriting Extracted/raw/1640_,.jpg
#   inflating: BanglaWriting Extracted/raw/16410_করেন.jpg
#   inflating: BanglaWriting Extracted/raw/16411_।.jpg
#   inflating: BanglaWriting Extracted/raw/16412_তিনি.jpg
#   inflating: BanglaWriting Extracted/raw/16413_মাসিক.jpg
#   inflating: BanglaWriting Extracted/raw/16414_মোহাম্মদী.jpg
#   inflating: BanglaWriting Extracted/raw/16416_মোহাম্মদী.jpg
#   inflating: BanglaWriting Extracted/raw/16417_,.jpg
#   inflating: BanglaWriting Extracted/raw/16418_দৈনিক.jpg
#   inflating: BanglaWriting Extracted/raw/16419_সেবক.jpg
#   inflating: BanglaWriting Extracted/raw/1641_নির্বাচন.jpg
#   inflating: BanglaWriting Extracted/raw/16420_,.jpg
#   inflating: BanglaWriting Extracted/raw/16421_সাপ্তাহিক.jpg
#   inflating: BanglaWriting Extracted/raw/16424_সাপ্তাহিক.jpg
#   inflating: BanglaWriting Extracted/raw/16425_খাদেম.jpg
#   inflating: BanglaWriting Extracted/raw/16426_,.jpg
#   inflating: BanglaWriting Extracted/raw/16428_দি.jpg
#   inflating: BanglaWriting Extracted/raw/16429_মুসলমান.jpg
#   inflating: BanglaWriting Extracted/raw/1642_,.jpg
#   inflating: BanglaWriting Extracted/raw/16430_ইত্যাদি.jpg
#   inflating: BanglaWriting Extracted/raw/16432_কমরত.jpg
#   inflating: BanglaWriting Extracted/raw/16433_ছিলেন.jpg
#   inflating: BanglaWriting Extracted/raw/16434_তার.jpg
#   inflating: BanglaWriting Extracted/raw/16435_উল্লেখযোগ্য.jpg
#   inflating: BanglaWriting Extracted/raw/16436_গ্রন্থ.jpg
#   inflating: BanglaWriting Extracted/raw/16437_মহামানুষ.jpg
#   inflating: BanglaWriting Extracted/raw/16438_মুহসীন.jpg
#   inflating: BanglaWriting Extracted/raw/16439_রুভাষ্কর.jpg
#   inflating: BanglaWriting Extracted/raw/1643_রাজনৈতিক.jpg
#   inflating: BanglaWriting Extracted/raw/16441_,.jpg
#   inflating: BanglaWriting Extracted/raw/16443_আহমদ.jpg
#   inflating: BanglaWriting Extracted/raw/16445_,.jpg
#   inflating: BanglaWriting Extracted/raw/16446_ছোট.jpg
#   inflating: BanglaWriting Extracted/raw/16449_মানুষ.jpg
#   inflating: BanglaWriting Extracted/raw/1644_দল.jpg
#   inflating: BanglaWriting Extracted/raw/16450_মুহম্মাদ.jpg
#   inflating: BanglaWriting Extracted/raw/16451_(স.).jpg
#   inflating: BanglaWriting Extracted/raw/16453_লেখক.jpg
#   inflating: BanglaWriting Extracted/raw/16454_-.jpg
#   inflating: BanglaWriting Extracted/raw/16455_পরিচিতিঃ.jpg
#   inflating: BanglaWriting Extracted/raw/16456_মোহাম্মদ.jpg
#   inflating: BanglaWriting Extracted/raw/16457_ওয়োজেদ.jpg
#   inflating: BanglaWriting Extracted/raw/16458_আলী.jpg
#   inflating: BanglaWriting Extracted/raw/16459_১৮৯৬.jpg
#   inflating: BanglaWriting Extracted/raw/1645_ইত্যাদি.jpg
#   inflating: BanglaWriting Extracted/raw/16460_সালে.jpg
#   inflating: BanglaWriting Extracted/raw/16461_(.jpg
#   inflating: BanglaWriting Extracted/raw/16463_শে.jpg
#   inflating: BanglaWriting Extracted/raw/16464_ভাদ্র.jpg
#   inflating: BanglaWriting Extracted/raw/16465_১৩০৩.jpg
#   inflating: BanglaWriting Extracted/raw/16466_সাল.jpg
#   inflating: BanglaWriting Extracted/raw/16467_).jpg
#   inflating: BanglaWriting Extracted/raw/16468_সাতক্ষীরা.jpg
#   inflating: BanglaWriting Extracted/raw/16469_জেলার.jpg
#   inflating: BanglaWriting Extracted/raw/1646_।.jpg
#   inflating: BanglaWriting Extracted/raw/16470_বাশঁদহ.jpg
#   inflating: BanglaWriting Extracted/raw/16471_গ্রামে.jpg
#   inflating: BanglaWriting Extracted/raw/16472_জন্মগ্রহন.jpg
#   inflating: BanglaWriting Extracted/raw/16473_করেন.jpg
#   inflating: BanglaWriting Extracted/raw/16474_।.jpg
#   inflating: BanglaWriting Extracted/raw/16475_কলকাতা.jpg
#   inflating: BanglaWriting Extracted/raw/16476_বঙ্গবাসী.jpg
#   inflating: BanglaWriting Extracted/raw/16477_কলেজে.jpg
#   inflating: BanglaWriting Extracted/raw/16479_বি.এ..jpg
#   inflating: BanglaWriting Extracted/raw/16480_ক্লাসের.jpg
#   inflating: BanglaWriting Extracted/raw/16481_ছাত্র.jpg
#   inflating: BanglaWriting Extracted/raw/16482_থাকাকালীন.jpg
#   inflating: BanglaWriting Extracted/raw/16483_তিনি.jpg
#   inflating: BanglaWriting Extracted/raw/16484_অসহযোগ.jpg
#   inflating: BanglaWriting Extracted/raw/16485_হিসেবে.jpg
#   inflating: BanglaWriting Extracted/raw/16486_গ্রহণ.jpg
#   inflating: BanglaWriting Extracted/raw/16487_করেন.jpg
#   inflating: BanglaWriting Extracted/raw/16488_।.jpg
#   inflating: BanglaWriting Extracted/raw/16489_তিনি.jpg
#   inflating: BanglaWriting Extracted/raw/1648_উৎপত্তি.jpg
#   inflating: BanglaWriting Extracted/raw/16490_মাসিক.jpg
#   inflating: BanglaWriting Extracted/raw/16491_'.jpg
#   inflating: BanglaWriting Extracted/raw/16492_মোহাম্মদী.jpg
#   inflating: BanglaWriting Extracted/raw/16493_,.jpg
#   inflating: BanglaWriting Extracted/raw/16494_দৈনিক.jpg
#   inflating: BanglaWriting Extracted/raw/16495_সেবক.jpg
#   inflating: BanglaWriting Extracted/raw/16497_বাদিক.jpg
#   inflating: BanglaWriting Extracted/raw/16498_তাকে.jpg
#   inflating: BanglaWriting Extracted/raw/16499_পেশা.jpg
#   inflating: BanglaWriting Extracted/raw/1649_,.jpg
#   inflating: BanglaWriting Extracted/raw/164_মোরা.jpg
#   inflating: BanglaWriting Extracted/raw/16500_হিসেবে.jpg
#   inflating: BanglaWriting Extracted/raw/16501_গ্রহণ.jpg
#   inflating: BanglaWriting Extracted/raw/16502_করে.jpg
#   inflating: BanglaWriting Extracted/raw/16503_।.jpg
#   inflating: BanglaWriting Extracted/raw/16504_সাপ্তাহিক.jpg
#   inflating: BanglaWriting Extracted/raw/16505_'.jpg
#   inflating: BanglaWriting Extracted/raw/16506_সওগাত.jpg
#   inflating: BanglaWriting Extracted/raw/16507_,.jpg
#   inflating: BanglaWriting Extracted/raw/16508_'.jpg
#   inflating: BanglaWriting Extracted/raw/16509_সাপ্তাহিক.jpg
#   inflating: BanglaWriting Extracted/raw/1650_প্রকৃতি.jpg
#   inflating: BanglaWriting Extracted/raw/16510_খাদেম.jpg
#   inflating: BanglaWriting Extracted/raw/16511_,.jpg
#   inflating: BanglaWriting Extracted/raw/16513_দি.jpg
#   inflating: BanglaWriting Extracted/raw/16514_মুসলমান.jpg
#   inflating: BanglaWriting Extracted/raw/16515_'.jpg
#   inflating: BanglaWriting Extracted/raw/16516_ইত্যাাদী.jpg
#   inflating: BanglaWriting Extracted/raw/16517_পত্রিকায়.jpg
#   inflating: BanglaWriting Extracted/raw/16518_কর্মরত.jpg
#   inflating: BanglaWriting Extracted/raw/16519_ছিলেন.jpg
#   inflating: BanglaWriting Extracted/raw/16538_।.jpg
#   inflating: BanglaWriting Extracted/raw/16539_তিনি.jpg
#   inflating: BanglaWriting Extracted/raw/1653_পৌরনীতি.jpg
#   inflating: BanglaWriting Extracted/raw/16540_খুব.jpg
#   inflating: BanglaWriting Extracted/raw/16541_পরিচ্ছন্ন.jpg
#   inflating: BanglaWriting Extracted/raw/16542_চিন্তা.jpg
#   inflating: BanglaWriting Extracted/raw/16543_ও.jpg
#   inflating: BanglaWriting Extracted/raw/16544_যুক্তি.jpg
#   inflating: BanglaWriting Extracted/raw/16546_ও.jpg
#   inflating: BanglaWriting Extracted/raw/16548_মন.jpg
#   inflating: BanglaWriting Extracted/raw/16549_নিয়ে.jpg
#   inflating: BanglaWriting Extracted/raw/1654_ও.jpg
#   inflating: BanglaWriting Extracted/raw/16550_সবকিছু.jpg
#   inflating: BanglaWriting Extracted/raw/16551_পুষ্টি.jpg
#   inflating: BanglaWriting Extracted/raw/16552_বিজ্ঞান.jpg
#   inflating: BanglaWriting Extracted/raw/16553_অনুসারে.jpg
#   inflating: BanglaWriting Extracted/raw/16554_আমরা.jpg
#   inflating: BanglaWriting Extracted/raw/16556_খাই.jpg
#   inflating: BanglaWriting Extracted/raw/16557_তার.jpg
#   inflating: BanglaWriting Extracted/raw/16558_^.jpg
#   inflating: BanglaWriting Extracted/raw/1655_নাগরিকতা.jpg
#   inflating: BanglaWriting Extracted/raw/16560_সবই.jpg
#   inflating: BanglaWriting Extracted/raw/16561_কিন্তু.jpg
#   inflating: BanglaWriting Extracted/raw/16562_খাদ্য.jpg
#   inflating: BanglaWriting Extracted/raw/16563_নয়.jpg
#   inflating: BanglaWriting Extracted/raw/16564_।.jpg
#   inflating: BanglaWriting Extracted/raw/16565_শুধু.jpg
#   inflating: BanglaWriting Extracted/raw/16566_সেই.jpg
#   inflating: BanglaWriting Extracted/raw/16567_সব.jpg
#   inflating: BanglaWriting Extracted/raw/16568_আহার্য.jpg
#   inflating: BanglaWriting Extracted/raw/16569_বস্তুকেই.jpg
#   inflating: BanglaWriting Extracted/raw/1656_বিষয়ে.jpg
#   inflating: BanglaWriting Extracted/raw/16570_খাদ্য.jpg
#   inflating: BanglaWriting Extracted/raw/16571_বলা.jpg
#   inflating: BanglaWriting Extracted/raw/16573_,.jpg
#   inflating: BanglaWriting Extracted/raw/16574_যে.jpg
#   inflating: BanglaWriting Extracted/raw/16575_গুলো.jpg
#   inflating: BanglaWriting Extracted/raw/16576_জীবদেহে.jpg
#   inflating: BanglaWriting Extracted/raw/16577_বৃদ্ধি.jpg
#   inflating: BanglaWriting Extracted/raw/16578_শক্তি.jpg
#   inflating: BanglaWriting Extracted/raw/16579_উৎপাদন.jpg
#   inflating: BanglaWriting Extracted/raw/1657_আলোচনা.jpg
#   inflating: BanglaWriting Extracted/raw/16580_রোগ.jpg
#   inflating: BanglaWriting Extracted/raw/16581_প্রতিরোধ.jpg
#   inflating: BanglaWriting Extracted/raw/16582_এবং.jpg
#   inflating: BanglaWriting Extracted/raw/16583_ক্ষয়পূরণ.jpg
#   inflating: BanglaWriting Extracted/raw/16584_করে.jpg
#   inflating: BanglaWriting Extracted/raw/16585_,.jpg
#   inflating: BanglaWriting Extracted/raw/16586_এক.jpg
#   inflating: BanglaWriting Extracted/raw/16587_কথা.jpg
#   inflating: BanglaWriting Extracted/raw/16588_দেহের.jpg
#   inflating: BanglaWriting Extracted/raw/1658_করা.jpg
#   inflating: BanglaWriting Extracted/raw/16590_সাধন.jpg
#   inflating: BanglaWriting Extracted/raw/16591_করে.jpg
#   inflating: BanglaWriting Extracted/raw/16592_।.jpg
#   inflating: BanglaWriting Extracted/raw/16593_পুষি.jpg
#   inflating: BanglaWriting Extracted/raw/16594_হলো.jpg
#   inflating: BanglaWriting Extracted/raw/16595_পরিবেশ.jpg
#   inflating: BanglaWriting Extracted/raw/16596_থেকে.jpg
#   inflating: BanglaWriting Extracted/raw/16597_প্রয়োজনীয়.jpg
#   inflating: BanglaWriting Extracted/raw/16598_খাদ্যবস্তু.jpg
#   inflating: BanglaWriting Extracted/raw/16599_আহরন.jpg
#   inflating: BanglaWriting Extracted/raw/1659_হয়.jpg
#   inflating: BanglaWriting Extracted/raw/165_ভাই.jpg
#   inflating: BanglaWriting Extracted/raw/16600_করে.jpg
#   inflating: BanglaWriting Extracted/raw/16601_খাদ্যবস্তুকে.jpg
#   inflating: BanglaWriting Extracted/raw/16602_পরিপাক.jpg
#   inflating: BanglaWriting Extracted/raw/16603_ও.jpg
#   inflating: BanglaWriting Extracted/raw/16605_করা.jpg
#   inflating: BanglaWriting Extracted/raw/16606_এবং.jpg
#   inflating: BanglaWriting Extracted/raw/16607_আত্তীকরণ.jpg
#   inflating: BanglaWriting Extracted/raw/16608_দ্বারা.jpg
#   inflating: BanglaWriting Extracted/raw/16609_দেহের.jpg
#   inflating: BanglaWriting Extracted/raw/1660_।.jpg
#   inflating: BanglaWriting Extracted/raw/16610_শক্তির.jpg
#   inflating: BanglaWriting Extracted/raw/16611_চাহিদা.jpg
#   inflating: BanglaWriting Extracted/raw/16612_পূরণ.jpg
#   inflating: BanglaWriting Extracted/raw/16613_করে.jpg
#   inflating: BanglaWriting Extracted/raw/16614_তাদের.jpg
#   inflating: BanglaWriting Extracted/raw/16615_এক.jpg
#   inflating: BanglaWriting Extracted/raw/16616_সঙ্গে.jpg
#   inflating: BanglaWriting Extracted/raw/16617_পরিপোষক.jpg
#   inflating: BanglaWriting Extracted/raw/16618_বলে.jpg
#   inflating: BanglaWriting Extracted/raw/16619_।.jpg
#   inflating: BanglaWriting Extracted/raw/1661_তা.jpg
#   inflating: BanglaWriting Extracted/raw/16622_ভূপৃষ্ঠের.jpg
#   inflating: BanglaWriting Extracted/raw/16623_পানি.jpg
#   inflating: BanglaWriting Extracted/raw/16624_প্রতিনিয়ত.jpg
#   inflating: BanglaWriting Extracted/raw/16625_নানাভাবে.jpg
#   inflating: BanglaWriting Extracted/raw/16626_হচ্ছে.jpg
#   inflating: BanglaWriting Extracted/raw/16627_।.jpg
#   inflating: BanglaWriting Extracted/raw/16629_এবার.jpg
#   inflating: BanglaWriting Extracted/raw/1662_ছাড়া.jpg
#   inflating: BanglaWriting Extracted/raw/16630_আমরা.jpg
#   inflating: BanglaWriting Extracted/raw/16631_সেই.jpg
#   inflating: BanglaWriting Extracted/raw/16632_দূষিত.jpg
#   inflating: BanglaWriting Extracted/raw/16633_দূষনের.jpg
#   inflating: BanglaWriting Extracted/raw/16634_কারণ.jpg
#   inflating: BanglaWriting Extracted/raw/16635_গুলো.jpg
#   inflating: BanglaWriting Extracted/raw/16636_আলোচনা.jpg
#   inflating: BanglaWriting Extracted/raw/16637_করব.jpg
#   inflating: BanglaWriting Extracted/raw/16638_।.jpg
#   inflating: BanglaWriting Extracted/raw/1663_সামাজিক.jpg
#   inflating: BanglaWriting Extracted/raw/16640_পানি.jpg
#   inflating: BanglaWriting Extracted/raw/16641_,.jpg
#   inflating: BanglaWriting Extracted/raw/16642_পায়খানা.jpg
#   inflating: BanglaWriting Extracted/raw/16643_বর্জ্য.jpg
#   inflating: BanglaWriting Extracted/raw/16644_পানি.jpg
#   inflating: BanglaWriting Extracted/raw/16645_কিংবা.jpg
#   inflating: BanglaWriting Extracted/raw/16646_অন্যান.jpg
#   inflating: BanglaWriting Extracted/raw/16647_কাজে.jpg
#   inflating: BanglaWriting Extracted/raw/16648_ব্যাবহার.jpg
#   inflating: BanglaWriting Extracted/raw/16649_পর.jpg
#   inflating: BanglaWriting Extracted/raw/1664_মূল্যবোধ.jpg
#   inflating: BanglaWriting Extracted/raw/16650_সেই.jpg
#   inflating: BanglaWriting Extracted/raw/16651_পরিত্যক্ত.jpg
#   inflating: BanglaWriting Extracted/raw/16652_পানি.jpg
#   inflating: BanglaWriting Extracted/raw/16653_কোথায়.jpg
#   inflating: BanglaWriting Extracted/raw/16654_যায়.jpg
#   inflating: BanglaWriting Extracted/raw/16656_সেটা.jpg
#   inflating: BanglaWriting Extracted/raw/16657_কি.jpg
#   inflating: BanglaWriting Extracted/raw/16658_তোমরা.jpg
#   inflating: BanglaWriting Extracted/raw/16659_জান.jpg
#   inflating: BanglaWriting Extracted/raw/1665_আইন.jpg
#   inflating: BanglaWriting Extracted/raw/16660_বর্জ্য.jpg
#   inflating: BanglaWriting Extracted/raw/16661_পানির.jpg
#   inflating: BanglaWriting Extracted/raw/16663_একটি.jpg
#   inflating: BanglaWriting Extracted/raw/16664_অংশ.jpg
#   inflating: BanglaWriting Extracted/raw/16665_নর্দমার.jpg
#   inflating: BanglaWriting Extracted/raw/16666_নলের.jpg
#   inflating: BanglaWriting Extracted/raw/16667_ভেতর.jpg
#   inflating: BanglaWriting Extracted/raw/16668_দিয়ে.jpg
#   inflating: BanglaWriting Extracted/raw/16669_নিয়ে.jpg
#   inflating: BanglaWriting Extracted/raw/1666_,.jpg
#   inflating: BanglaWriting Extracted/raw/16670_নদ.jpg
#   inflating: BanglaWriting Extracted/raw/16671_-.jpg
#   inflating: BanglaWriting Extracted/raw/16674_ফলা.jpg
#   inflating: BanglaWriting Extracted/raw/16676_হয়.jpg
#   inflating: BanglaWriting Extracted/raw/16678_এবং.jpg
#   inflating: BanglaWriting Extracted/raw/16679_সেগুলো.jpg
#   inflating: BanglaWriting Extracted/raw/1667_স্বাধীনতা.jpg
#   inflating: BanglaWriting Extracted/raw/16680_পানিকে.jpg
#   inflating: BanglaWriting Extracted/raw/16681_রা.jpg
#   inflating: BanglaWriting Extracted/raw/16683_ত্মক.jpg
#   inflating: BanglaWriting Extracted/raw/16684_ভাবে.jpg
#   inflating: BanglaWriting Extracted/raw/16685_দূষিত.jpg
#   inflating: BanglaWriting Extracted/raw/16686_করে.jpg
#   inflating: BanglaWriting Extracted/raw/16687_এই.jpg
#   inflating: BanglaWriting Extracted/raw/16688_বর্জ্য.jpg
#   inflating: BanglaWriting Extracted/raw/16689_পানিতে.jpg
#   inflating: BanglaWriting Extracted/raw/1668_ও.jpg
#   inflating: BanglaWriting Extracted/raw/16690_রোগ.jpg
#   inflating: BanglaWriting Extracted/raw/16691_বানু.jpg
#   inflating: BanglaWriting Extracted/raw/16693_থেকে.jpg
#   inflating: BanglaWriting Extracted/raw/16694_শুরু.jpg
#   inflating: BanglaWriting Extracted/raw/16695_করে.jpg
#   inflating: BanglaWriting Extracted/raw/16696_নানারকম.jpg
#   inflating: BanglaWriting Extracted/raw/16697_রাসায়নিক.jpg
#   inflating: BanglaWriting Extracted/raw/16698_স্তু.jpg
#   inflating: BanglaWriting Extracted/raw/16699_থাকে.jpg
#   inflating: BanglaWriting Extracted/raw/16717_সামথ্য.jpg
#   inflating: BanglaWriting Extracted/raw/16718_নেই.jpg
#   inflating: BanglaWriting Extracted/raw/16719_বেড়াবার.jpg
#   inflating: BanglaWriting Extracted/raw/1671_সংবিধান.jpg
#   inflating: BanglaWriting Extracted/raw/16720_,.jpg
#   inflating: BanglaWriting Extracted/raw/16721_যাদের.jpg
#   inflating: BanglaWriting Extracted/raw/16722_আছে.jpg
#   inflating: BanglaWriting Extracted/raw/16723_তাদের.jpg
#   inflating: BanglaWriting Extracted/raw/16724_প্রতি.jpg
#   inflating: BanglaWriting Extracted/raw/16725_চেয়ে.jpg
#   inflating: BanglaWriting Extracted/raw/16726_চেয়ে.jpg
#   inflating: BanglaWriting Extracted/raw/16727_দেখি.jpg
#   inflating: BanglaWriting Extracted/raw/16728_।.jpg
#   inflating: BanglaWriting Extracted/raw/16729_দেখতাম.jpg
#   inflating: BanglaWriting Extracted/raw/1672_,.jpg
#   inflating: BanglaWriting Extracted/raw/16730_মধ্যবিত্ত.jpg
#   inflating: BanglaWriting Extracted/raw/16731_গৃহস্থের.jpg
#   inflating: BanglaWriting Extracted/raw/16639_গোসলের.jpg
#   inflating: BanglaWriting Extracted/raw/16655_,.jpg
#   inflating: BanglaWriting Extracted/raw/16673_নদিতে.jpg
#   inflating: BanglaWriting Extracted/raw/1669_সাম্য.jpg
#   inflating: BanglaWriting Extracted/raw/16716_নিজের.jpg
#   inflating: BanglaWriting Extracted/raw/16732_ঘরে.jpg
#   inflating: BanglaWriting Extracted/raw/16749_এরা.jpg
#   inflating: BanglaWriting Extracted/raw/16765_মোজা.jpg
#   inflating: BanglaWriting Extracted/raw/16782_মহান.jpg
#   inflating: BanglaWriting Extracted/raw/16799_হয়.jpg
#   inflating: BanglaWriting Extracted/raw/16815_হবে.jpg
#   inflating: BanglaWriting Extracted/raw/16832_।.jpg
#   inflating: BanglaWriting Extracted/raw/1685_নাগরিকের.jpg
#   inflating: BanglaWriting Extracted/raw/16879_ব্যাখ্যাঃ.jpg
#   inflating: BanglaWriting Extracted/raw/16895_সে.jpg
#   inflating: BanglaWriting Extracted/raw/16911_আল্লাহ.jpg
#   inflating: BanglaWriting Extracted/raw/16733_পীড়িতদের.jpg
#   inflating: BanglaWriting Extracted/raw/16734_মধ্যে.jpg
#   inflating: BanglaWriting Extracted/raw/16735_মেয়েদের.jpg
#   inflating: BanglaWriting Extracted/raw/16736_সংখ্যাই.jpg
#   inflating: BanglaWriting Extracted/raw/16737_ঢের.jpg
#   inflating: BanglaWriting Extracted/raw/16738_বেশি.jpg
#   inflating: BanglaWriting Extracted/raw/16739_প্রথমেই.jpg
#   inflating: BanglaWriting Extracted/raw/1673_জনমত.jpg
#   inflating: BanglaWriting Extracted/raw/16740_যেত.jpg
#   inflating: BanglaWriting Extracted/raw/16741_পা.jpg
#   inflating: BanglaWriting Extracted/raw/16742_ফুলো.jpg
#   inflating: BanglaWriting Extracted/raw/16743_-.jpg
#   inflating: BanglaWriting Extracted/raw/16744_ফুলো.jpg
#   inflating: BanglaWriting Extracted/raw/16745_অল্পবয়সী.jpg
#   inflating: BanglaWriting Extracted/raw/16746_একদল.jpg
#   inflating: BanglaWriting Extracted/raw/16747_মেয়ে.jpg
#   inflating: BanglaWriting Extracted/raw/16748_বুঝতাম.jpg
#   inflating: BanglaWriting Extracted/raw/1674_প্রকৃতি.jpg
#   inflating: BanglaWriting Extracted/raw/16750_বেরিবেরির.jpg
#   inflating: BanglaWriting Extracted/raw/16751_আসামি.jpg
#   inflating: BanglaWriting Extracted/raw/16752_।.jpg
#   inflating: BanglaWriting Extracted/raw/16753_মোজা.jpg
#   inflating: BanglaWriting Extracted/raw/16754_পড়ার.jpg
#   inflating: BanglaWriting Extracted/raw/16755_দিন.jpg
#   inflating: BanglaWriting Extracted/raw/16756_নয়.jpg
#   inflating: BanglaWriting Extracted/raw/16757_কিন্তু.jpg
#   inflating: BanglaWriting Extracted/raw/16758_তবু.jpg
#   inflating: BanglaWriting Extracted/raw/16759_দেখি.jpg
#   inflating: BanglaWriting Extracted/raw/1675_পৌরনীতি.jpg
#   inflating: BanglaWriting Extracted/raw/16760_কার.jpg
#   inflating: BanglaWriting Extracted/raw/16761_ও.jpg
#   inflating: BanglaWriting Extracted/raw/16762_পায়ে.jpg
#   inflating: BanglaWriting Extracted/raw/16763_আঁট.jpg
#   inflating: BanglaWriting Extracted/raw/16764_করে.jpg
#   inflating: BanglaWriting Extracted/raw/16766_পড়া.jpg
#   inflating: BanglaWriting Extracted/raw/16767_।.jpg
#   inflating: BanglaWriting Extracted/raw/16768_আর.jpg
#   inflating: BanglaWriting Extracted/raw/16769_সবচেয়ে.jpg
#   inflating: BanglaWriting Extracted/raw/1676_ও.jpg
#   inflating: BanglaWriting Extracted/raw/16770_দুঃখ.jpg
#   inflating: BanglaWriting Extracted/raw/16771_হতো.jpg
#   inflating: BanglaWriting Extracted/raw/16772_আমার.jpg
#   inflating: BanglaWriting Extracted/raw/16773_দরিদ্র.jpg
#   inflating: BanglaWriting Extracted/raw/16774_ঘরের.jpg
#   inflating: BanglaWriting Extracted/raw/16775_মেয়ে.jpg
#   inflating: BanglaWriting Extracted/raw/16777_দেখে.jpg
#   inflating: BanglaWriting Extracted/raw/16778_।.jpg
#   inflating: BanglaWriting Extracted/raw/16779_১৯৭১.jpg
#   inflating: BanglaWriting Extracted/raw/1677_নাগরিকতার.jpg
#   inflating: BanglaWriting Extracted/raw/16780_সালে.jpg
#   inflating: BanglaWriting Extracted/raw/16781_বাংলাদেশে.jpg
#   inflating: BanglaWriting Extracted/raw/16783_মুক্তিযুদ্ধ.jpg
#   inflating: BanglaWriting Extracted/raw/16784_সংঘটিত.jpg
#   inflating: BanglaWriting Extracted/raw/16785_হয়.jpg
#   inflating: BanglaWriting Extracted/raw/16786_।.jpg
#   inflating: BanglaWriting Extracted/raw/16787_নয়.jpg
#   inflating: BanglaWriting Extracted/raw/16788_মাস.jpg
#   inflating: BanglaWriting Extracted/raw/16789_পাকিস্তান.jpg
#   inflating: BanglaWriting Extracted/raw/1678_আলোচ্য.jpg
#   inflating: BanglaWriting Extracted/raw/16790_সেনাবাহিনীর.jpg
#   inflating: BanglaWriting Extracted/raw/16791_বিরুদ্ধে.jpg
#   inflating: BanglaWriting Extracted/raw/16792_প্রানপন.jpg
#   inflating: BanglaWriting Extracted/raw/16793_লড়াই.jpg
#   inflating: BanglaWriting Extracted/raw/16794_করে.jpg
#   inflating: BanglaWriting Extracted/raw/16795_১৬.jpg
#   inflating: BanglaWriting Extracted/raw/16796_ডিসেম্বর.jpg
#   inflating: BanglaWriting Extracted/raw/16797_আমাদের.jpg
#   inflating: BanglaWriting Extracted/raw/16798_শত্রুমুক্ত.jpg
#   inflating: BanglaWriting Extracted/raw/1679_বিষয়.jpg
#   inflating: BanglaWriting Extracted/raw/167_একসাথে.jpg
#   inflating: BanglaWriting Extracted/raw/16800_।.jpg
#   inflating: BanglaWriting Extracted/raw/16801_মুক্তিযুদ্ধ.jpg
#   inflating: BanglaWriting Extracted/raw/16802_আমাদের.jpg
#   inflating: BanglaWriting Extracted/raw/16803_গর্বের.jpg
#   inflating: BanglaWriting Extracted/raw/16804_গৌরবের.jpg
#   inflating: BanglaWriting Extracted/raw/16805_কাহিনী.jpg
#   inflating: BanglaWriting Extracted/raw/16806_।.jpg
#   inflating: BanglaWriting Extracted/raw/16807_আছে.jpg
#   inflating: BanglaWriting Extracted/raw/16808_।.jpg
#   inflating: BanglaWriting Extracted/raw/16809_সেসব.jpg
#   inflating: BanglaWriting Extracted/raw/1680_।.jpg
#   inflating: BanglaWriting Extracted/raw/16811_জানতে.jpg
#   inflating: BanglaWriting Extracted/raw/16812_হলে.jpg
#   inflating: BanglaWriting Extracted/raw/16813_ইতিহাস.jpg
#   inflating: BanglaWriting Extracted/raw/16814_পড়তে.jpg
#   inflating: BanglaWriting Extracted/raw/16816_,.jpg
#   inflating: BanglaWriting Extracted/raw/16817_চর্চা.jpg
#   inflating: BanglaWriting Extracted/raw/16818_করতে.jpg
#   inflating: BanglaWriting Extracted/raw/16819_হবে.jpg
#   inflating: BanglaWriting Extracted/raw/1681_পৌরনীতি.jpg
#   inflating: BanglaWriting Extracted/raw/16820_।.jpg
#   inflating: BanglaWriting Extracted/raw/16821_ইতিহাস.jpg
#   inflating: BanglaWriting Extracted/raw/16822_সত্য.jpg
#   inflating: BanglaWriting Extracted/raw/16823_ঘটনা.jpg
#   inflating: BanglaWriting Extracted/raw/16824_উপস্থাপন.jpg
#   inflating: BanglaWriting Extracted/raw/16825_করে.jpg
#   inflating: BanglaWriting Extracted/raw/16826_।.jpg
#   inflating: BanglaWriting Extracted/raw/16827_ইতিহাস.jpg
#   inflating: BanglaWriting Extracted/raw/16828_সম্পর্কে.jpg
#   inflating: BanglaWriting Extracted/raw/16829_অবহি.jpg
#   inflating: BanglaWriting Extracted/raw/1682_ও.jpg
#   inflating: BanglaWriting Extracted/raw/16830_হতে.jpg
#   inflating: BanglaWriting Extracted/raw/16831_পারে.jpg
#   inflating: BanglaWriting Extracted/raw/16833_যেতে.jpg
#   inflating: BanglaWriting Extracted/raw/16834_যেতে.jpg
#   inflating: BanglaWriting Extracted/raw/16835_পথে.jpg
#   inflating: BanglaWriting Extracted/raw/16836_পূর্ণিমা.jpg
#   inflating: BanglaWriting Extracted/raw/16837_রাতে.jpg
#   inflating: BanglaWriting Extracted/raw/16838_,.jpg
#   inflating: BanglaWriting Extracted/raw/16839_চাঁদ.jpg
#   inflating: BanglaWriting Extracted/raw/1683_নাগরিকতা.jpg
#   inflating: BanglaWriting Extracted/raw/16840_উঠেছিল.jpg
#   inflating: BanglaWriting Extracted/raw/16841_গগনে.jpg
#   inflating: BanglaWriting Extracted/raw/16842_-.jpg
#   inflating: BanglaWriting Extracted/raw/16843_-.jpg
#   inflating: BanglaWriting Extracted/raw/16844_-.jpg
#   inflating: BanglaWriting Extracted/raw/16845_-.jpg
#   inflating: BanglaWriting Extracted/raw/16846_-.jpg
#   inflating: BanglaWriting Extracted/raw/16847_-.jpg
#   inflating: BanglaWriting Extracted/raw/16848_।.jpg
#   inflating: BanglaWriting Extracted/raw/16849_আমারো.jpg
#   inflating: BanglaWriting Extracted/raw/1684_বিষয়টি.jpg
#   inflating: BanglaWriting Extracted/raw/16850_পরানো.jpg
#   inflating: BanglaWriting Extracted/raw/16851_যাহা.jpg
#   inflating: BanglaWriting Extracted/raw/16852_যায়.jpg
#   inflating: BanglaWriting Extracted/raw/16853_,.jpg
#   inflating: BanglaWriting Extracted/raw/16854_তুমি.jpg
#   inflating: BanglaWriting Extracted/raw/16855_তাই.jpg
#   inflating: BanglaWriting Extracted/raw/16856_রক্ত.jpg
#   inflating: BanglaWriting Extracted/raw/16857_দিয়েছি.jpg
#   inflating: BanglaWriting Extracted/raw/16858_আরো.jpg
#   inflating: BanglaWriting Extracted/raw/16859_দিব.jpg
#   inflating: BanglaWriting Extracted/raw/16950_-.jpg
#   inflating: BanglaWriting Extracted/raw/16951_৫৩.jpg
#   inflating: BanglaWriting Extracted/raw/16952_আমাদের.jpg
#   inflating: BanglaWriting Extracted/raw/16953_ভুল.jpg
#   inflating: BanglaWriting Extracted/raw/16954_হলে.jpg
#   inflating: BanglaWriting Extracted/raw/16955_সাথে.jpg
#   inflating: BanglaWriting Extracted/raw/16956_সাথে.jpg
#   inflating: BanglaWriting Extracted/raw/16957_আল্লাহ.jpg
#   inflating: BanglaWriting Extracted/raw/16958_তায়ালা.jpg
#   inflating: BanglaWriting Extracted/raw/1695_নির্ণয়.jpg
#   inflating: BanglaWriting Extracted/raw/16960_কাছে.jpg
#   inflating: BanglaWriting Extracted/raw/16961_ক্ষমা.jpg
#   inflating: BanglaWriting Extracted/raw/16962_চাইব.jpg
#   inflating: BanglaWriting Extracted/raw/16963_।.jpg
#   inflating: BanglaWriting Extracted/raw/16964_আল্লাহ.jpg
#   inflating: BanglaWriting Extracted/raw/16965_আমাদের.jpg
#   inflating: BanglaWriting Extracted/raw/16966_মাফ.jpg
#   inflating: BanglaWriting Extracted/raw/1687_বর্তমান.jpg
#   inflating: BanglaWriting Extracted/raw/16880_মানুষ.jpg
#   inflating: BanglaWriting Extracted/raw/16881_শয়তানের.jpg
#   inflating: BanglaWriting Extracted/raw/16882_প্ররোচনায়.jpg
#   inflating: BanglaWriting Extracted/raw/16883_পড়ে.jpg
#   inflating: BanglaWriting Extracted/raw/16884_অন্যায়.jpg
#   inflating: BanglaWriting Extracted/raw/16885_করে.jpg
#   inflating: BanglaWriting Extracted/raw/16886_ফেলে.jpg
#   inflating: BanglaWriting Extracted/raw/16887_।.jpg
#   inflating: BanglaWriting Extracted/raw/16888_পাপ.jpg
#   inflating: BanglaWriting Extracted/raw/16889_কর্ম.jpg
#   inflating: BanglaWriting Extracted/raw/1688_ও.jpg
#   inflating: BanglaWriting Extracted/raw/16890_করে.jpg
#   inflating: BanglaWriting Extracted/raw/16891_বসে.jpg
#   inflating: BanglaWriting Extracted/raw/16892_।.jpg
#   inflating: BanglaWriting Extracted/raw/16893_তখন.jpg
#   inflating: BanglaWriting Extracted/raw/16894_যদি.jpg
#   inflating: BanglaWriting Extracted/raw/16896_অনুতপ্ত.jpg
#   inflating: BanglaWriting Extracted/raw/16897_হয়.jpg
#   inflating: BanglaWriting Extracted/raw/16898_,.jpg
# ...
#   inflating: BanglaWriting Extracted/raw/20972_উপর.jpg
#   inflating: BanglaWriting Extracted/raw/20973_নির্ভরশীল.jpg
#   inflating: BanglaWriting Extracted/raw/20974_হার.jpg
#   inflating: BanglaWriting Extracted/raw/20975_পড়েন.jpg
#   inflating: BanglaWriting Extracted/raw/20976_।.jpg
#   inflating: BanglaWriting Extracted/raw/20977_জীবন.jpg
#   inflating: BanglaWriting Extracted/raw/20978_সৃষ্টির.jpg
#   inflating: BanglaWriting Extracted/raw/20979_সময়কাল.jpg
#   inflating: BanglaWriting Extracted/raw/20980_পৃথিবীর.jpg
#   inflating: BanglaWriting Extracted/raw/20981_শিলাস্তরে.jpg
#   inflating: BanglaWriting Extracted/raw/20982_প্রাপ্ত.jpg
#   inflating: BanglaWriting Extracted/raw/20983_কিছু.jpg
#   inflating: BanglaWriting Extracted/raw/20984_চিহ্ন.jpg
#   inflating: BanglaWriting Extracted/raw/20985_আদি.jpg
#   inflating: BanglaWriting Extracted/raw/20986_জীবের.jpg
#   inflating: BanglaWriting Extracted/raw/20987_নিদর্শন.jpg
#   inflating: BanglaWriting Extracted/raw/20988_বহন.jpg
#   inflating: BanglaWriting Extracted/raw/20989_করে.jpg
#   inflating: BanglaWriting Extracted/raw/2098_রাতের.jpg
#   inflating: BanglaWriting Extracted/raw/20990_।.jpg
#   inflating: BanglaWriting Extracted/raw/20991_এই.jpg
#   inflating: BanglaWriting Extracted/raw/20992_চিহ্নগুলো.jpg
#   inflating: BanglaWriting Extracted/raw/20993_মূলত.jpg
#   inflating: BanglaWriting Extracted/raw/20994_আদি.jpg
#   inflating: BanglaWriting Extracted/raw/20995_জীব.jpg
#   inflating: BanglaWriting Extracted/raw/20997_প্রোক্যারিওট.jpg
#   inflating: BanglaWriting Extracted/raw/20998_গোত্রের.jpg
#   inflating: BanglaWriting Extracted/raw/20999_ব্যাক্টেরিয়া.jpg
#   inflating: BanglaWriting Extracted/raw/2099_জনসংখ্যা.jpg
#   inflating: BanglaWriting Extracted/raw/209_ক্ষেতে.jpg
#   inflating: BanglaWriting Extracted/raw/20_,.jpg
#   inflating: BanglaWriting Extracted/raw/21000_বিশেষ.jpg
#   inflating: BanglaWriting Extracted/raw/21001_।.jpg
#   inflating: BanglaWriting Extracted/raw/21002_এমন.jpg
#   inflating: BanglaWriting Extracted/raw/21003_প্রাচীন.jpg
#   inflating: BanglaWriting Extracted/raw/21004_জীবের.jpg
#   inflating: BanglaWriting Extracted/raw/21005_চিহ্ন.jpg
#   inflating: BanglaWriting Extracted/raw/21006_বহনকারী.jpg
#   inflating: BanglaWriting Extracted/raw/21007_শিলার.jpg
#   inflating: BanglaWriting Extracted/raw/21008_বয়স.jpg
#   inflating: BanglaWriting Extracted/raw/21009_প্রায়.jpg
#   inflating: BanglaWriting Extracted/raw/2100_বৃদ্ধির.jpg
#   inflating: BanglaWriting Extracted/raw/21011_..jpg
#   inflating: BanglaWriting Extracted/raw/21012_৫.jpg
#   inflating: BanglaWriting Extracted/raw/21013_বিলিয়ন.jpg
#   inflating: BanglaWriting Extracted/raw/21014_বছর.jpg
#   inflating: BanglaWriting Extracted/raw/21015_।.jpg
#   inflating: BanglaWriting Extracted/raw/21016_সুতরাং.jpg
#   inflating: BanglaWriting Extracted/raw/21017_স্পষ্ট.jpg
#   inflating: BanglaWriting Extracted/raw/21018_করে.jpg
#   inflating: BanglaWriting Extracted/raw/21019_বলা.jpg
#   inflating: BanglaWriting Extracted/raw/2101_হার.jpg
#   inflating: BanglaWriting Extracted/raw/21020_যায়.jpg
#   inflating: BanglaWriting Extracted/raw/21021_জীবনের.jpg
#   inflating: BanglaWriting Extracted/raw/21022_আবির্ভাব.jpg
#   inflating: BanglaWriting Extracted/raw/21023_হয়েছে.jpg
#   inflating: BanglaWriting Extracted/raw/21024_এর.jpg
#   inflating: BanglaWriting Extracted/raw/21025_ও.jpg
#   inflating: BanglaWriting Extracted/raw/21026_অনেক.jpg
#   inflating: BanglaWriting Extracted/raw/21027_পূর্বে.jpg
#   inflating: BanglaWriting Extracted/raw/21028_।.jpg
#   inflating: BanglaWriting Extracted/raw/21029_ধারণা.jpg
#   inflating: BanglaWriting Extracted/raw/21047_ভাগে.jpg
#   inflating: BanglaWriting Extracted/raw/21048_বিভক্ত.jpg
#   inflating: BanglaWriting Extracted/raw/21049_ছিল.jpg
#   inflating: BanglaWriting Extracted/raw/2104_সকলে.jpg
#   inflating: BanglaWriting Extracted/raw/21050_।.jpg
#   inflating: BanglaWriting Extracted/raw/21051_একটির.jpg
#   inflating: BanglaWriting Extracted/raw/21052_নাম.jpg
#   inflating: BanglaWriting Extracted/raw/21053_পূর্ব.jpg
#   inflating: BanglaWriting Extracted/raw/21054_পাকিস্থান.jpg
#   inflating: BanglaWriting Extracted/raw/21055_অন্যটির.jpg
#   inflating: BanglaWriting Extracted/raw/21056_নাম.jpg
#   inflating: BanglaWriting Extracted/raw/21057_পশ্চিম.jpg
#   inflating: BanglaWriting Extracted/raw/21058_পাকিস্থান.jpg
#   inflating: BanglaWriting Extracted/raw/21059_।.jpg
#   inflating: BanglaWriting Extracted/raw/2105_আগামীতে.jpg
#   inflating: BanglaWriting Extracted/raw/21060_আমরা.jpg
#   inflating: BanglaWriting Extracted/raw/21061_পূর্ব.jpg
#   inflating: BanglaWriting Extracted/raw/21063_অধিবাসী.jpg
#   inflating: BanglaWriting Extracted/raw/21064_ছিলাম.jpg
#   inflating: BanglaWriting Extracted/raw/21065_।.jpg
#   inflating: BanglaWriting Extracted/raw/21066_পশ্চিম.jpg
#   inflating: BanglaWriting Extracted/raw/21067_পাকিস্তানের.jpg
#   inflating: BanglaWriting Extracted/raw/21068_-.jpg
#   inflating: BanglaWriting Extracted/raw/21069_লোকেরা.jpg
#   inflating: BanglaWriting Extracted/raw/2106_আমাদের.jpg
#   inflating: BanglaWriting Extracted/raw/21070_আমাদের.jpg
#   inflating: BanglaWriting Extracted/raw/21071_উপর.jpg
#   inflating: BanglaWriting Extracted/raw/21072_চরম.jpg
#   inflating: BanglaWriting Extracted/raw/21073_অত্যাচার.jpg
#   inflating: BanglaWriting Extracted/raw/21074_করতো.jpg
#   inflating: BanglaWriting Extracted/raw/21075_।.jpg
#   inflating: BanglaWriting Extracted/raw/21076_তাদের.jpg
#   inflating: BanglaWriting Extracted/raw/21077_ভাষা.jpg
#   inflating: BanglaWriting Extracted/raw/21078_ছিল.jpg
#   inflating: BanglaWriting Extracted/raw/2107_মতো.jpg
#   inflating: BanglaWriting Extracted/raw/21080_।.jpg
#   inflating: BanglaWriting Extracted/raw/21081_আর.jpg
#   inflating: BanglaWriting Extracted/raw/21082_আমাদের.jpg
#   inflating: BanglaWriting Extracted/raw/21083_ভাষা.jpg
#   inflating: BanglaWriting Extracted/raw/21084_ছিল.jpg
#   inflating: BanglaWriting Extracted/raw/21085_বাংলা.jpg
#   inflating: BanglaWriting Extracted/raw/21086_।.jpg
#   inflating: BanglaWriting Extracted/raw/21087_যাকে.jpg
#   inflating: BanglaWriting Extracted/raw/21088_আমরা.jpg
#   inflating: BanglaWriting Extracted/raw/21089_মাতৃভাষা.jpg
#   inflating: BanglaWriting Extracted/raw/2108_দেশের.jpg
#   inflating: BanglaWriting Extracted/raw/21090_বলে.jpg
#   inflating: BanglaWriting Extracted/raw/21091_ডাকি.jpg
#   inflating: BanglaWriting Extracted/raw/21092_।.jpg
#   inflating: BanglaWriting Extracted/raw/21093_১৯৫২.jpg
#   inflating: BanglaWriting Extracted/raw/21094_সালে.jpg
#   inflating: BanglaWriting Extracted/raw/21096_নিয়ে.jpg
#   inflating: BanglaWriting Extracted/raw/21097_যেই.jpg
#   inflating: BanglaWriting Extracted/raw/21098_আন্দোলন.jpg
#   inflating: BanglaWriting Extracted/raw/21099_হয়েছিল.jpg
#   inflating: BanglaWriting Extracted/raw/2109_খাদ্যসংকট.jpg
#   inflating: BanglaWriting Extracted/raw/210_কি.jpg
#   inflating: BanglaWriting Extracted/raw/21100_তার.jpg
#   inflating: BanglaWriting Extracted/raw/21101_নাম.jpg
#   inflating: BanglaWriting Extracted/raw/21102_ছিল.jpg
#   inflating: BanglaWriting Extracted/raw/21103_ভাষা.jpg
#   inflating: BanglaWriting Extracted/raw/21104_আন্দোলন.jpg
#   inflating: BanglaWriting Extracted/raw/21105_।.jpg
#   inflating: BanglaWriting Extracted/raw/21106_আর.jpg
#   inflating: BanglaWriting Extracted/raw/21107_সেই.jpg
#   inflating: BanglaWriting Extracted/raw/21108_আন্দোলনে.jpg
#   inflating: BanglaWriting Extracted/raw/21109_বাঙালিরা.jpg
#   inflating: BanglaWriting Extracted/raw/2110_হচ্ছে.jpg
#   inflating: BanglaWriting Extracted/raw/21111_লাভ.jpg
#   inflating: BanglaWriting Extracted/raw/21112_করে.jpg
#   inflating: BanglaWriting Extracted/raw/21113_।.jpg
#   inflating: BanglaWriting Extracted/raw/21114_অনেক.jpg
#   inflating: BanglaWriting Extracted/raw/21115_রক্তের.jpg
#   inflating: BanglaWriting Extracted/raw/21116_বিনিময়ে.jpg
#   inflating: BanglaWriting Extracted/raw/21117_আমরা.jpg
#   inflating: BanglaWriting Extracted/raw/21118_বাংলা.jpg
#   inflating: BanglaWriting Extracted/raw/21119_ভাষায়.jpg
#   inflating: BanglaWriting Extracted/raw/2111_আরো.jpg
#   inflating: BanglaWriting Extracted/raw/21120_এখন.jpg
#   inflating: BanglaWriting Extracted/raw/21121_কথা.jpg
#   inflating: BanglaWriting Extracted/raw/21122_বলতে.jpg
#   inflating: BanglaWriting Extracted/raw/21123_পারছি.jpg
#   inflating: BanglaWriting Extracted/raw/21124_।.jpg
#   inflating: BanglaWriting Extracted/raw/21125_আর.jpg
#   inflating: BanglaWriting Extracted/raw/21126_১৯৭১.jpg
#   inflating: BanglaWriting Extracted/raw/21128_হয়েছিল.jpg
#   inflating: BanglaWriting Extracted/raw/21129_মুক্তিযোদ্ধ.jpg
#   inflating: BanglaWriting Extracted/raw/2112_কী.jpg
#   inflating: BanglaWriting Extracted/raw/21130_।.jpg
#   inflating: BanglaWriting Extracted/raw/21131_সেই.jpg
#   inflating: BanglaWriting Extracted/raw/21132_মুক্তিযোদ্ধে.jpg
#   inflating: BanglaWriting Extracted/raw/21133_প্রায়.jpg
#   inflating: BanglaWriting Extracted/raw/21134_ত্রিশ.jpg
#   inflating: BanglaWriting Extracted/raw/21135_লক্ষ.jpg
#   inflating: BanglaWriting Extracted/raw/21136_মানুষ.jpg
#   inflating: BanglaWriting Extracted/raw/21137_শহীদ.jpg
#   inflating: BanglaWriting Extracted/raw/21138_হয়েছিলেন.jpg
#   inflating: BanglaWriting Extracted/raw/21139_।.jpg
#   inflating: BanglaWriting Extracted/raw/2113_পরিমান.jpg
#   inflating: BanglaWriting Extracted/raw/21140_আমরা.jpg
#   inflating: BanglaWriting Extracted/raw/21141_তাদের.jpg
#   inflating: BanglaWriting Extracted/raw/21142_প্রতি.jpg
#   inflating: BanglaWriting Extracted/raw/21144_।.jpg
#   inflating: BanglaWriting Extracted/raw/21145_শহীদদের.jpg
#   inflating: BanglaWriting Extracted/raw/21146_ঋণ.jpg
#   inflating: BanglaWriting Extracted/raw/21147_আমরা.jpg
#   inflating: BanglaWriting Extracted/raw/21148_কোনোদিন.jpg
#   inflating: BanglaWriting Extracted/raw/21149_শোধ.jpg
#   inflating: BanglaWriting Extracted/raw/2114_বারছে.jpg
#   inflating: BanglaWriting Extracted/raw/21150_করতে.jpg
#   inflating: BanglaWriting Extracted/raw/21151_পারবো.jpg
#   inflating: BanglaWriting Extracted/raw/21152_না.jpg
#   inflating: BanglaWriting Extracted/raw/21153_।.jpg
#   inflating: BanglaWriting Extracted/raw/21154_সকল.jpg
#   inflating: BanglaWriting Extracted/raw/21155_বিক্রিয়ার.jpg
#   inflating: BanglaWriting Extracted/raw/21156_সাম্যাবস্থার.jpg
#   inflating: BanglaWriting Extracted/raw/21157_উপর.jpg
#   inflating: BanglaWriting Extracted/raw/21158_বিক্রিয়াকে.jpg
#   inflating: BanglaWriting Extracted/raw/21159_ঘনমাত্রার.jpg
#   inflating: BanglaWriting Extracted/raw/21160_প্রভাব.jpg
#   inflating: BanglaWriting Extracted/raw/21161_রয়েছে.jpg
#   inflating: BanglaWriting Extracted/raw/21162_।.jpg
#   inflating: BanglaWriting Extracted/raw/21163_বিক্রিয়ার.jpg
#   inflating: BanglaWriting Extracted/raw/21164_সাম্যাব.jpg
#   inflating: BanglaWriting Extracted/raw/21165_স্থায়.jpg
#   inflating: BanglaWriting Extracted/raw/21166_যে.jpg
#   inflating: BanglaWriting Extracted/raw/21167_কোনো.jpg
#   inflating: BanglaWriting Extracted/raw/21168_একটি.jpg
#   inflating: BanglaWriting Extracted/raw/21169_বিক্রিয়াকের.jpg
#   inflating: BanglaWriting Extracted/raw/2116_আমাদের.jpg
#   inflating: BanglaWriting Extracted/raw/21170_ঘনমাত্রা.jpg
#   inflating: BanglaWriting Extracted/raw/21171_বাড়ালে.jpg
#   inflating: BanglaWriting Extracted/raw/21172_লা.jpg
#   inflating: BanglaWriting Extracted/raw/21173_-.jpg
#   inflating: BanglaWriting Extracted/raw/21174_শাতেলিয়ার.jpg
#   inflating: BanglaWriting Extracted/raw/21175_নীতি.jpg
#   inflating: BanglaWriting Extracted/raw/21177_বিক্রিয়াকের.jpg
#   inflating: BanglaWriting Extracted/raw/21178_ঘনমাত্রা.jpg
#   inflating: BanglaWriting Extracted/raw/21179_কমিয়ে.jpg
#   inflating: BanglaWriting Extracted/raw/2117_আগামীতে.jpg
#   inflating: BanglaWriting Extracted/raw/21180_পরিবর্তনের.jpg
#   inflating: BanglaWriting Extracted/raw/21181_ফলাফলকে.jpg
#   inflating: BanglaWriting Extracted/raw/21182_প্রশমিত.jpg
#   inflating: BanglaWriting Extracted/raw/21183_করার.jpg
#   inflating: BanglaWriting Extracted/raw/21184_জন্য.jpg
#   inflating: BanglaWriting Extracted/raw/21185_উৎপাদের.jpg
#   inflating: BanglaWriting Extracted/raw/21186_পরিমান.jpg
#   inflating: BanglaWriting Extracted/raw/21187_বৃদ্ধি.jpg
#   inflating: BanglaWriting Extracted/raw/21188_করতে.jpg
#   inflating: BanglaWriting Extracted/raw/21189_হবে.jpg
#   inflating: BanglaWriting Extracted/raw/2118_আমাদের.jpg
#   inflating: BanglaWriting Extracted/raw/21190_।.jpg
#   inflating: BanglaWriting Extracted/raw/21191_আমরা.jpg
#   inflating: BanglaWriting Extracted/raw/21192_বলতে.jpg
#   inflating: BanglaWriting Extracted/raw/21193_পারি.jpg
#   inflating: BanglaWriting Extracted/raw/21194_,.jpg
#   inflating: BanglaWriting Extracted/raw/21195_এখানে.jpg
#   inflating: BanglaWriting Extracted/raw/21196_বিক্রিয়ার.jpg
#   inflating: BanglaWriting Extracted/raw/21197_সাম্যাবস্থা.jpg
#   inflating: BanglaWriting Extracted/raw/21198_ডান.jpg
#   inflating: BanglaWriting Extracted/raw/21199_দিকে.jpg
#   inflating: BanglaWriting Extracted/raw/2119_মতো.jpg
#   inflating: BanglaWriting Extracted/raw/21217_বিপরিত.jpg
#   inflating: BanglaWriting Extracted/raw/21218_দিকে.jpg
#   inflating: BanglaWriting Extracted/raw/21219_ঘটতে.jpg
#   inflating: BanglaWriting Extracted/raw/2121_রাতের.jpg
#   inflating: BanglaWriting Extracted/raw/21220_থাকে.jpg
#   inflating: BanglaWriting Extracted/raw/21221_এবং.jpg
#   inflating: BanglaWriting Extracted/raw/21222_বিক্রিয়াকের.jpg
#   inflating: BanglaWriting Extracted/raw/21223_ঘনমাত্রা.jpg
#   inflating: BanglaWriting Extracted/raw/21224_বৃদ্ধি.jpg
#   inflating: BanglaWriting Extracted/raw/21225_হতে.jpg
#   inflating: BanglaWriting Extracted/raw/21226_থাকে.jpg
#   inflating: BanglaWriting Extracted/raw/21227_।.jpg
#   inflating: BanglaWriting Extracted/raw/21228_অন্যভাবে.jpg
#   inflating: BanglaWriting Extracted/raw/21229_আমরা.jpg
#   inflating: BanglaWriting Extracted/raw/2122_আমদানি.jpg
#   inflating: BanglaWriting Extracted/raw/21230_বলেতে.jpg
#   inflating: BanglaWriting Extracted/raw/21231_।.jpg
#   inflating: BanglaWriting Extracted/raw/21233_০.jpg
#   inflating: BanglaWriting Extracted/raw/2123_আলো.jpg
#   inflating: BanglaWriting Extracted/raw/2124_আমাদের.jpg
#   inflating: BanglaWriting Extracted/raw/2125_এদের.jpg
#   inflating: BanglaWriting Extracted/raw/2126_অমাদের.jpg
#   inflating: BanglaWriting Extracted/raw/2128_হিসাববিজ্ঞানের.jpg
#   inflating: BanglaWriting Extracted/raw/2129_মাধ্যমে.jpg
#   inflating: BanglaWriting Extracted/raw/212_আমি.jpg
#   inflating: BanglaWriting Extracted/raw/2130_ব্যবসায়.jpg
#   inflating: BanglaWriting Extracted/raw/2131_অতীত.jpg
#   inflating: BanglaWriting Extracted/raw/2132_কার্যাবলি.jpg
#   inflating: BanglaWriting Extracted/raw/2133_,.jpg
#   inflating: BanglaWriting Extracted/raw/2134_বর্তমান.jpg
#   inflating: BanglaWriting Extracted/raw/2135_কর্মকান্ড.jpg
#   inflating: BanglaWriting Extracted/raw/2136_এবং.jpg
#   inflating: BanglaWriting Extracted/raw/21046_দুইটি.jpg
#   inflating: BanglaWriting Extracted/raw/21062_পাকিস্তানের.jpg
#   inflating: BanglaWriting Extracted/raw/21079_উর্দু.jpg
#   inflating: BanglaWriting Extracted/raw/21095_মাতৃভাষা.jpg
#   inflating: BanglaWriting Extracted/raw/21110_জয়.jpg
#   inflating: BanglaWriting Extracted/raw/21127_সালে.jpg
#   inflating: BanglaWriting Extracted/raw/21143_কৃতজ্ঞিত.jpg
#   inflating: BanglaWriting Extracted/raw/2115_এদের.jpg
#   inflating: BanglaWriting Extracted/raw/21176_অনুসারে.jpg
#   inflating: BanglaWriting Extracted/raw/211_দেখেছি.jpg
#   inflating: BanglaWriting Extracted/raw/21216_বিক্রিয়াটির.jpg
#   inflating: BanglaWriting Extracted/raw/2137_ভবিষ্যতের.jpg
#   inflating: BanglaWriting Extracted/raw/2156_।.jpg
#   inflating: BanglaWriting Extracted/raw/2173_ধীরে.jpg
#   inflating: BanglaWriting Extracted/raw/2190_জবাবদিহিতা.jpg
#   inflating: BanglaWriting Extracted/raw/2207_চষাজমিতে.jpg

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# Dataset

# %%
import random
import torch
from torch.utils.data import Dataset
from torch.utils.data import sampler
import torchvision.transforms as transforms
import lmdb
import six
import sys
from PIL import Image
import numpy as np


class lmdbDataset(Dataset):

    def __init__(self, root=None, transform=None, target_transform=None):
        self.env = lmdb.open(
            root,
            max_readers=1,
            readonly=True,
            lock=False,
            readahead=False,
            meminit=False)

        if not self.env:
            print('cannot creat lmdb from %s' % (root))
            sys.exit(0)

        with self.env.begin(write=False) as txn:
            nSamples = int(txn.get('num-samples'))
            self.nSamples = nSamples

        self.transform = transform
        self.target_transform = target_transform

    def __len__(self):
        return self.nSamples

    def __getitem__(self, index):
        assert index <= len(self), 'index range error'
        index += 1
        with self.env.begin(write=False) as txn:
            img_key = 'image-%09d' % index
            imgbuf = txn.get(img_key)

            buf = six.BytesIO()
            buf.write(imgbuf)
            buf.seek(0)
            try:
                img = Image.open(buf).convert('L')
            except IOError:
                print('Corrupted image for %d' % index)
                return self[index + 1]

            if self.transform is not None:
                img = self.transform(img)

            label_key = 'label-%09d' % index
            label = str(txn.get(label_key))

            if self.target_transform is not None:
                label = self.target_transform(label)

        return (img, label)


class resizeNormalize(object):

    def __init__(self, size, interpolation=Image.BILINEAR):
        self.size = size
        self.interpolation = interpolation
        self.toTensor = transforms.ToTensor()

    def __call__(self, img):
        img = img.resize(self.size, self.interpolation)
        img = self.toTensor(img)
        img.sub_(0.5).div_(0.5)
        return img


class randomSequentialSampler(sampler.Sampler):

    def __init__(self, data_source, batch_size):
        self.num_samples = len(data_source)
        self.batch_size = batch_size

    def __iter__(self):
        n_batch = len(self) // self.batch_size
        tail = len(self) % self.batch_size
        index = torch.LongTensor(len(self)).fill_(0)
        for i in range(n_batch):
            random_start = random.randint(0, len(self) - self.batch_size)
            batch_index = random_start + torch.range(0, self.batch_size - 1)
            index[i * self.batch_size:(i + 1) * self.batch_size] = batch_index
        # deal with tail
        if tail:
            random_start = random.randint(0, len(self) - self.batch_size)
            tail_index = random_start + torch.range(0, tail - 1)
            index[(i + 1) * self.batch_size:] = tail_index

        return iter(index)

    def __len__(self):
        return self.num_samples


class alignCollate(object):

    def __init__(self, imgH=32, imgW=100, keep_ratio=False, min_ratio=1):
        self.imgH = imgH
        self.imgW = imgW
        self.keep_ratio = keep_ratio
        self.min_ratio = min_ratio

    def __call__(self, batch):
        images, labels = zip(*batch)

        imgH = self.imgH
        imgW = self.imgW
        if self.keep_ratio:
            ratios = []
            for image in images:
                w, h = image.size
                ratios.append(w / float(h))
            ratios.sort()
            max_ratio = ratios[-1]
            imgW = int(np.floor(max_ratio * imgH))
            imgW = max(imgH * self.min_ratio, imgW)  # assure imgH >= imgW

        transform = resizeNormalize((imgW, imgH))
        images = [transform(image) for image in images]
        images = torch.cat([t.unsqueeze(0) for t in images], 0)

        return images, labels

# %% [markdown]
# Utils

# %%
pip install torchfile
# Out:
# Collecting torchfile
#   Downloading https://files.pythonhosted.org/packages/91/af/5b305f86f2d218091af657ddb53f984ecbd9518ca9fe8ef4103a007252c9/torchfile-0.1.0.tar.gz
# Building wheels for collected packages: torchfile
#   Building wheel for torchfile (setup.py) ... done
#   Created wheel for torchfile: filename=torchfile-0.1.0-cp36-none-any.whl size=5711 sha256=1cb4d0e40adf469f0a725978f3847b34796fce5e56afd11c83a32f11c83dfa30
#   Stored in directory: /root/.cache/pip/wheels/b1/c3/d6/9a1cc8f3a99a0fc1124cae20153f36af59a6e683daca0a0814
# Successfully built torchfile
# Installing collected packages: torchfile
# Successfully installed torchfile-0.1.0

# %%
import torch
import torch.nn as nn
from torch.autograd import Variable
import collections


class strLabelConverter(object):
    """Convert between str and label.
    NOTE:
        Insert `blank` to the alphabet for CTC.
    Args:
        alphabet (str): set of the possible characters.
        ignore_case (bool, default=True): whether or not to ignore all of the case.
    """

    def __init__(self, alphabet, ignore_case=True):
        self._ignore_case = ignore_case
        if self._ignore_case:
            alphabet = alphabet.lower()
        self.alphabet = alphabet + '-'  # for `-1` index

        self.dict = {}
        for i, char in enumerate(alphabet):
            # NOTE: 0 is reserved for 'blank' required by wrap_ctc
            self.dict[char] = i + 1

    def encode(self, text):
        """Support batch or single str.
        Args:
            text (str or list of str): texts to convert.
        Returns:
            torch.IntTensor [length_0 + length_1 + ... length_{n - 1}]: encoded texts.
            torch.IntTensor [n]: length of each text.
        """
        if isinstance(text, str):
            text = [
                self.dict[char.lower() if self._ignore_case else char]
                for char in text
            ]
            length = [len(text)]
        elif isinstance(text, collections.Iterable):
            length = [len(s) for s in text]
            text = ''.join(text)
            text, _ = self.encode(text)
        return (torch.IntTensor(text), torch.IntTensor(length))

    def decode(self, t, length, raw=False):
        """Decode encoded texts back into strs.
        Args:
            torch.IntTensor [length_0 + length_1 + ... length_{n - 1}]: encoded texts.
            torch.IntTensor [n]: length of each text.
        Raises:
            AssertionError: when the texts and its length does not match.
        Returns:
            text (str or list of str): texts to convert.
        """
        if length.numel() == 1:
            length = length[0]
            assert t.numel() == length, "text with length: {} does not match declared length: {}".format(t.numel(), length)
            if raw:
                return ''.join([self.alphabet[i - 1] for i in t])
            else:
                char_list = []
                for i in range(length):
                    if t[i] != 0 and (not (i > 0 and t[i - 1] == t[i])):
                        char_list.append(self.alphabet[t[i] - 1])
                return ''.join(char_list)
        else:
            # batch mode
            assert t.numel() == length.sum(), "texts with length: {} does not match declared length: {}".format(t.numel(), length.sum())
            texts = []
            index = 0
            for i in range(length.numel()):
                l = length[i]
                texts.append(
                    self.decode(
                        t[index:index + l], torch.IntTensor([l]), raw=raw))
                index += l
            return texts


class averager(object):
    """Compute average for `torch.Variable` and `torch.Tensor`. """

    def __init__(self):
        self.reset()

    def add(self, v):
        if isinstance(v, Variable):
            count = v.data.numel()
            v = v.data.sum()
        elif isinstance(v, torch.Tensor):
            count = v.numel()
            v = v.sum()

        self.n_count += count
        self.sum += v

    def reset(self):
        self.n_count = 0
        self.sum = 0

    def val(self):
        res = 0
        if self.n_count != 0:
            res = self.sum / float(self.n_count)
        return res


def oneHot(v, v_length, nc):
    batchSize = v_length.size(0)
    maxLength = v_length.max()
    v_onehot = torch.FloatTensor(batchSize, maxLength, nc).fill_(0)
    acc = 0
    for i in range(batchSize):
        length = v_length[i]
        label = v[acc:acc + length].view(-1, 1).long()
        v_onehot[i, :length].scatter_(1, label, 1.0)
        acc += length
    return v_onehot


def loadData(v, data):
    v.data.resize_(data.size()).copy_(data)


def prettyPrint(v):
    print('Size {0}, Type: {1}'.format(str(v.size()), v.data.type()))
    print('| Max: %f | Min: %f | Mean: %f' % (v.max().data[0], v.min().data[0],
                                              v.mean().data[0]))


def assureRatio(img):
    """Ensure imgH <= imgW."""
    b, c, h, w = img.size()
    if h > w:
        main = nn.UpsamplingBilinear2d(size=(h, h), scale_factor=None)
        img = main(img)
    return img

# %% [markdown]
# Model

# %%
import torch.nn as nn


class BidirectionalLSTM(nn.Module):

    def __init__(self, nIn, nHidden, nOut):
        super(BidirectionalLSTM, self).__init__()

        self.rnn = nn.LSTM(nIn, nHidden, bidirectional=True)
        self.embedding = nn.Linear(nHidden * 2, nOut)

    def forward(self, input):
        recurrent, _ = self.rnn(input)
        T, b, h = recurrent.size()
        t_rec = recurrent.view(T * b, h)

        output = self.embedding(t_rec)  # [T * b, nOut]
        output = output.view(T, b, -1)

        return output


class CRNN(nn.Module):

    def __init__(self, imgH, nc, nclass, nh, n_rnn=2, leakyRelu=False):
        super(CRNN, self).__init__()
        assert imgH % 16 == 0, 'imgH has to be a multiple of 16'

        ks = [3, 3, 3, 3, 3, 3, 2]
        ps = [1, 1, 1, 1, 1, 1, 0]
        ss = [1, 1, 1, 1, 1, 1, 1]
        nm = [64, 128, 256, 256, 512, 512, 512]

        cnn = nn.Sequential()

        def convRelu(i, batchNormalization=False):
            nIn = nc if i == 0 else nm[i - 1]
            nOut = nm[i]
            cnn.add_module('conv{0}'.format(i),
                           nn.Conv2d(nIn, nOut, ks[i], ss[i], ps[i]))
            if batchNormalization:
                cnn.add_module('batchnorm{0}'.format(i), nn.BatchNorm2d(nOut))
            if leakyRelu:
                cnn.add_module('relu{0}'.format(i),
                               nn.LeakyReLU(0.2, inplace=True))
            else:
                cnn.add_module('relu{0}'.format(i), nn.ReLU(True))

        convRelu(0)
        cnn.add_module('pooling{0}'.format(0), nn.MaxPool2d(2, 2))  # 64x16x64
        convRelu(1)
        cnn.add_module('pooling{0}'.format(1), nn.MaxPool2d(2, 2))  # 128x8x32
        convRelu(2, True)
        convRelu(3)
        cnn.add_module('pooling{0}'.format(2),
                       nn.MaxPool2d((2, 2), (2, 1), (0, 1)))  # 256x4x16
        convRelu(4, True)
        convRelu(5)
        cnn.add_module('pooling{0}'.format(3),
                       nn.MaxPool2d((2, 2), (2, 1), (0, 1)))  # 512x2x16
        convRelu(6, True)  # 512x1x16

        self.cnn = cnn
        self.rnn = nn.Sequential(
            BidirectionalLSTM(512, nh, nh),
            BidirectionalLSTM(nh, nh, nclass))

    def forward(self, input):
        # conv features
        conv = self.cnn(input)
        b, c, h, w = conv.size()
        assert h == 1, "the height of conv must be 1"
        conv = conv.squeeze(2)
        conv = conv.permute(2, 0, 1)  # [w, b, c]

        # rnn features
        output = self.rnn(conv)

        return output

# %% [markdown]
# Tool

# %%
import torchfile

import torch
from torch.nn.parameter import Parameter
import numpy as np



layer_map = {
    'SpatialConvolution': 'Conv2d',
    'SpatialBatchNormalization': 'BatchNorm2d',
    'ReLU': 'ReLU',
    'SpatialMaxPooling': 'MaxPool2d',
    'SpatialAveragePooling': 'AvgPool2d',
    'SpatialUpSamplingNearest': 'UpsamplingNearest2d',
    'View': None,
    'Linear': 'linear',
    'Dropout': 'Dropout',
    'SoftMax': 'Softmax',
    'Identity': None,
    'SpatialFullConvolution': 'ConvTranspose2d',
    'SpatialReplicationPadding': None,
    'SpatialReflectionPadding': None,
    'Copy': None,
    'Narrow': None,
    'SpatialCrossMapLRN': None,
    'Sequential': None,
    'ConcatTable': None,  # output is list
    'CAddTable': None,  # input is list
    'Concat': None,
    'TorchObject': None,
    'LstmLayer': 'LSTM',
    'BiRnnJoin': 'Linear'
}


def torch_layer_serial(layer, layers):
    name = layer[0]
    if name == 'nn.Sequential' or name == 'nn.ConcatTable':
        tmp_layers = []
        for sub_layer in layer[1]:
            torch_layer_serial(sub_layer, tmp_layers)
        layers.extend(tmp_layers)
    else:
        layers.append(layer)


def py_layer_serial(layer, layers):
    """
    Assume modules are defined as executive sequence.
    """
    if len(layer._modules) >= 1:
        tmp_layers = []
        for sub_layer in layer.children():
            py_layer_serial(sub_layer, tmp_layers)
        layers.extend(tmp_layers)
    else:
        layers.append(layer)


def trans_pos(param, part_indexes, dim=0):
    parts = np.split(param, len(part_indexes), dim)
    new_parts = []
    for i in part_indexes:
        new_parts.append(parts[i])
    return np.concatenate(new_parts, dim)


def load_params(py_layer, t7_layer):
    if type(py_layer).__name__ == 'LSTM':
        # LSTM
        all_weights = []
        num_directions = 2 if py_layer.bidirectional else 1
        for i in range(py_layer.num_layers):
            for j in range(num_directions):
                suffix = '_reverse' if j == 1 else ''
                weights = ['weight_ih_l{}{}', 'bias_ih_l{}{}',
                           'weight_hh_l{}{}', 'bias_hh_l{}{}']
                weights = [x.format(i, suffix) for x in weights]
                all_weights += weights

        params = []
        for i in range(len(t7_layer)):
            params.extend(t7_layer[i][1])
        params = [trans_pos(p, [0, 1, 3, 2], dim=0) for p in params]
    else:
        all_weights = []
        name = t7_layer[0].split('.')[-1]
        if name == 'BiRnnJoin':
            weight_0, bias_0, weight_1, bias_1 = t7_layer[1]
            weight = np.concatenate((weight_0, weight_1), axis=1)
            bias = bias_0 + bias_1
            t7_layer[1] = [weight, bias]
            all_weights += ['weight', 'bias']
        elif name == 'SpatialConvolution' or name == 'Linear':
            all_weights += ['weight', 'bias']
        elif name == 'SpatialBatchNormalization':
            all_weights += ['weight', 'bias', 'running_mean', 'running_var']

        params = t7_layer[1]

    params = [torch.from_numpy(item) for item in params]
    assert len(all_weights) == len(params), "params' number not match"
    for py_param_name, t7_param in zip(all_weights, params):
        item = getattr(py_layer, py_param_name)
        if isinstance(item, Parameter):
            item = item.data
        try:
            item.copy_(t7_param)
        except RuntimeError:
            print('Size not match between %s and %s' %
                  (item.size(), t7_param.size()))


def torch_to_pytorch(model, t7_file, output):
    py_layers = []
    for layer in list(model.children()):
        py_layer_serial(layer, py_layers)

    t7_data = torchfile.load(t7_file)
    t7_layers = []
    for layer in t7_data:
        torch_layer_serial(layer, t7_layers)

    j = 0
    for i, py_layer in enumerate(py_layers):
        py_name = type(py_layer).__name__
        t7_layer = t7_layers[j]
        t7_name = t7_layer[0].split('.')[-1]
        if layer_map[t7_name] != py_name:
            raise RuntimeError('%s does not match %s' % (py_name, t7_name))

        if py_name == 'LSTM':
            n_layer = 2 if py_layer.bidirectional else 1
            n_layer *= py_layer.num_layers
            t7_layer = t7_layers[j:j + n_layer]
            j += n_layer
        else:
            j += 1

        load_params(py_layer, t7_layer)

    torch.save(model.state_dict(), output)


if __name__ == "__main__":

    py_model = CRNN(32, 1, 37, 256, 1)

# %% [markdown]
# Train

# %%
pip install warpctc_pytorch
# Out:
# Collecting warpctc_pytorch
#   Downloading https://files.pythonhosted.org/packages/52/22/03cfb35a1f91c2d0d1e1e44134398ef210e080e076ddc4ac26a6336803ed/warpctc_pytorch-0.2.1%2Btorch16.cuda92-cp36-cp36m-manylinux1_x86_64.whl (3.0MB)
#      |████████████████████████████████| 3.1MB 18.7MB/s
# Installing collected packages: warpctc-pytorch
# Successfully installed warpctc-pytorch-0.2.1

# %%
# !pip install kora
from kora import console
console.start()
# Out:
# Collecting kora
#   Downloading https://files.pythonhosted.org/packages/55/e9/60b70219b513fce09cb839860689bc1421d31afe98da1517c81ff26fd741/kora-0.9.13-py3-none-any.whl (55kB)
#      |████████████████████████████████| 61kB 7.5MB/s
# Collecting fastcore
#   Downloading https://files.pythonhosted.org/packages/b6/ec/fb511797e16be60f55d33e34ee228240c4e3a3960bb22ba8a03ab2a83e59/fastcore-1.3.11-py3-none-any.whl (51kB)
#      |████████████████████████████████| 61kB 7.5MB/s
# Requirement already satisfied: ipython in /usr/local/lib/python3.6/dist-packages (from kora) (5.5.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.6/dist-packages (from fastcore->kora) (20.4)
# Requirement already satisfied: pip in /usr/local/lib/python3.6/dist-packages (from fastcore->kora) (19.3.1)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.6/dist-packages (from ipython->kora) (50.3.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.6/dist-packages (from ipython->kora) (0.7.5)
# Requirement already satisfied: simplegeneric>0.8 in /usr/local/lib/python3.6/dist-packages (from ipython->kora) (0.8.1)
# Requirement already satisfied: traitlets>=4.2 in /usr/local/lib/python3.6/dist-packages (from ipython->kora) (4.3.3)
# Requirement already satisfied: pexpect; sys_platform != "win32" in /usr/local/lib/python3.6/dist-packages (from ipython->kora) (4.8.0)
# Requirement already satisfied: pygments in /usr/local/lib/python3.6/dist-packages (from ipython->kora) (2.6.1)
# Requirement already satisfied: prompt-toolkit<2.0.0,>=1.0.4 in /usr/local/lib/python3.6/dist-packages (from ipython->kora) (1.0.18)
# Requirement already satisfied: decorator in /usr/local/lib/python3.6/dist-packages (from ipython->kora) (4.4.2)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from packaging->fastcore->kora) (1.15.0)
# Requirement already satisfied: pyparsing>=2.0.2 in /usr/local/lib/python3.6/dist-packages (from packaging->fastcore->kora) (2.4.7)
# Requirement already satisfied: ipython-genutils in /usr/local/lib/python3.6/dist-packages (from traitlets>=4.2->ipython->kora) (0.2.0)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.6/dist-packages (from pexpect; sys_platform != "win32"->ipython->kora) (0.6.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.6/dist-packages (from prompt-toolkit<2.0.0,>=1.0.4->ipython->kora) (0.2.5)
# Installing collected packages: fastcore, kora
# Successfully installed fastcore-1.3.11 kora-0.9.13
# Console URL: https://as.teleconsole.com/s/d1334a8aa3832086a7e2a9407b3d014bd4c75147

# %%
from __future__ import print_function
from __future__ import division

import argparse
import random
import torch
import torch.backends.cudnn as cudnn
import torch.optim as optim
import torch.utils.data
from torch.autograd import Variable
import numpy as np
from torch import nn
import os





parser = argparse.ArgumentParser()
parser.add_argument('--trainRoot', required=True, help='path to dataset')
parser.add_argument('--valRoot', required=True, help='path to dataset')
parser.add_argument('--workers', type=int, help='number of data loading workers', default=2)
parser.add_argument('--batchSize', type=int, default=64, help='input batch size')
parser.add_argument('--imgH', type=int, default=32, help='the height of the input image to network')
parser.add_argument('--imgW', type=int, default=100, help='the width of the input image to network')
parser.add_argument('--nh', type=int, default=256, help='size of the lstm hidden state')
parser.add_argument('--nepoch', type=int, default=25, help='number of epochs to train for')
# TODO(meijieru): epoch -> iter
parser.add_argument('--cuda', action='store_true', help='enables cuda')
parser.add_argument('--ngpu', type=int, default=1, help='number of GPUs to use')
parser.add_argument('--pretrained', default='', help="path to pretrained model (to continue training)")
parser.add_argument('--alphabet', type=str, default='0123456789abcdefghijklmnopqrstuvwxyz')
parser.add_argument('--expr_dir', default='expr', help='Where to store samples and models')
parser.add_argument('--displayInterval', type=int, default=500, help='Interval to be displayed')
parser.add_argument('--n_test_disp', type=int, default=10, help='Number of samples to display when test')
parser.add_argument('--valInterval', type=int, default=500, help='Interval to be displayed')
parser.add_argument('--saveInterval', type=int, default=500, help='Interval to be displayed')
parser.add_argument('--lr', type=float, default=0.01, help='learning rate for Critic, not used by adadealta')
parser.add_argument('--beta1', type=float, default=0.5, help='beta1 for adam. default=0.5')
parser.add_argument('--adam', action='store_true', help='Whether to use adam (default is rmsprop)')
parser.add_argument('--adadelta', action='store_true', help='Whether to use adadelta (default is rmsprop)')
parser.add_argument('--keep_ratio', action='store_true', help='whether to keep ratio for image resize')
parser.add_argument('--manualSeed', type=int, default=1234, help='reproduce experiemnt')
parser.add_argument('--random_sample', action='store_true', help='whether to sample the dataset with random sampler')
opt = parser.parse_args()
print(opt)

if not os.path.exists(opt.expr_dir):
    os.makedirs(opt.expr_dir)

random.seed(opt.manualSeed)
np.random.seed(opt.manualSeed)
torch.manual_seed(opt.manualSeed)

cudnn.benchmark = True

if torch.cuda.is_available() and not opt.cuda:
    print("WARNING: You have a CUDA device, so you should probably run with --cuda")

train_dataset = lmdbDataset(root=opt.trainroot)
assert train_dataset
if not opt.random_sample:
    sampler = randomSequentialSampler(train_dataset, opt.batchSize)
else:
    sampler = None
train_loader = torch.utils.data.DataLoader(
    train_dataset, batch_size=opt.batchSize,
    shuffle=True, sampler=sampler,
    num_workers=int(opt.workers),
    collate_fn=alignCollate(imgH=opt.imgH, imgW=opt.imgW, keep_ratio=opt.keep_ratio))
test_dataset = lmdbDataset(
    root=opt.valroot, transform=resizeNormalize((100, 32)))

nclass = len(opt.alphabet) + 1
nc = 1

converter = strLabelConverter(opt.alphabet)
criterion = nn.CTCLoss()


# custom weights initialization called on crnn
def weights_init(m):
    classname = m.__class__.__name__
    if classname.find('Conv') != -1:
        m.weight.data.normal_(0.0, 0.02)
    elif classname.find('BatchNorm') != -1:
        m.weight.data.normal_(1.0, 0.02)
        m.bias.data.fill_(0)


crnn = CRNN(opt.imgH, nc, nclass, opt.nh)
apply(weights_init)
if opt.pretrained != '':
    print('loading pretrained model from %s' % opt.pretrained)
    load_state_dict(torch.load(opt.pretrained))
print(crnn)

image = torch.FloatTensor(opt.batchSize, 3, opt.imgH, opt.imgH)
text = torch.IntTensor(opt.batchSize * 5)
length = torch.IntTensor(opt.batchSize)

if opt.cuda:
    cuda()
    crnn = torch.nn.DataParallel(crnn, device_ids=range(opt.ngpu))
    image = image.cuda()
    criterion = criterion.cuda()

image = Variable(image)
text = Variable(text)
length = Variable(length)

# loss averager
loss_avg = averager()

# setup optimizer
if opt.adam:
    optimizer = optim.Adam(parameters(), lr=opt.lr,
                           betas=(opt.beta1, 0.999))
elif opt.adadelta:
    optimizer = optim.Adadelta(parameters())
else:
    optimizer = optim.RMSprop(parameters(), lr=opt.lr)


def val(net, dataset, criterion, max_iter=100):
    print('Start val')

    for p in parameters():
        p.requires_grad = False

    net.eval()
    data_loader = torch.utils.data.DataLoader(
        dataset, shuffle=True, batch_size=opt.batchSize, num_workers=int(opt.workers))
    val_iter = iter(data_loader)

    i = 0
    n_correct = 0
    loss_avg = averager()

    max_iter = min(max_iter, len(data_loader))
    for i in range(max_iter):
        data = val_iter.next()
        i += 1
        cpu_images, cpu_texts = data
        batch_size = cpu_images.size(0)
        loadData(image, cpu_images)
        t, l = converter.encode(cpu_texts)
        loadData(text, t)
        loadData(length, l)

        preds = crnn(image)
        preds_size = Variable(torch.IntTensor([preds.size(0)] * batch_size))
        cost = criterion(preds, text, preds_size, length) / batch_size
        loss_avg.add(cost)

        _, preds = preds.max(2)
        preds = preds.squeeze(2)
        preds = preds.transpose(1, 0).contiguous().view(-1)
        sim_preds = converter.decode(preds.data, preds_size.data, raw=False)
        for pred, target in zip(sim_preds, cpu_texts):
            if pred == target.lower():
                n_correct += 1

    raw_preds = converter.decode(preds.data, preds_size.data, raw=True)[:opt.n_test_disp]
    for raw_pred, pred, gt in zip(raw_preds, sim_preds, cpu_texts):
        print('%-20s => %-20s, gt: %-20s' % (raw_pred, pred, gt))

    accuracy = n_correct / float(max_iter * opt.batchSize)
    print('Test loss: %f, accuray: %f' % (loss_avg.val(), accuracy))


def trainBatch(net, criterion, optimizer):
    data = train_iter.next()
    cpu_images, cpu_texts = data
    batch_size = cpu_images.size(0)
    loadData(image, cpu_images)
    t, l = converter.encode(cpu_texts)
    loadData(text, t)
    loadData(length, l)

    preds = crnn(image)
    preds_size = Variable(torch.IntTensor([preds.size(0)] * batch_size))
    cost = criterion(preds, text, preds_size, length) / batch_size
    zero_grad()
    cost.backward()
    optimizer.step()
    return cost


for epoch in range(opt.nepoch):
    train_iter = iter(train_loader)
    i = 0
    while i < len(train_loader):
        for p in parameters():
            p.requires_grad = True
        train()

        cost = trainBatch(crnn, criterion, optimizer)
        loss_avg.add(cost)
        i += 1

        if i % opt.displayInterval == 0:
            print('[%d/%d][%d/%d] Loss: %f' %
                  (epoch, opt.nepoch, i, len(train_loader), loss_avg.val()))
            loss_avg.reset()

        if i % opt.valInterval == 0:
            val(crnn, test_dataset, criterion)

        # do checkpointing
        if i % opt.saveInterval == 0:
            torch.save(
                state_dict(), '{0}/netCRNN_{1}_{2}.pth'.format(opt.expr_dir, epoch, i))
# Out:
# usage: ipykernel_launcher.py [-h] --trainRoot TRAINROOT --valRoot VALROOT
#                              [--workers WORKERS] [--batchSize BATCHSIZE]
#                              [--imgH IMGH] [--imgW IMGW] [--nh NH]
#                              [--nepoch NEPOCH] [--cuda] [--ngpu NGPU]
#                              [--pretrained PRETRAINED] [--alphabet ALPHABET]
#                              [--expr_dir EXPR_DIR]
#                              [--displayInterval DISPLAYINTERVAL]
#                              [--n_test_disp N_TEST_DISP]
#                              [--valInterval VALINTERVAL]
#                              [--saveInterval SAVEINTERVAL] [--lr LR]
#                              [--beta1 BETA1] [--adam] [--adadelta]
#                              [--keep_ratio] [--manualSeed MANUALSEED]
#                              [--random_sample]
# ipykernel_launcher.py: error: the following arguments are required: --trainRoot, --valRoot
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 2
# /usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py:2890: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)
